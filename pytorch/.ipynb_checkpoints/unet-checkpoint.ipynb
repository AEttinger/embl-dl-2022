# %% [markdown]
# <a href="https://colab.research.google.com/github/constantinpape/training-deep-learning-models-for-vison/blob/master/day3/unet_pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Training a U-net
#
# The [U-net](https://lmb.informatik.uni-freiburg.de/people/ronneber/u-net/) is a very popular model architecture for segmentation in bioimage analysis.
# Here, we will train a 2D U-net for nuclei segmentation, using data from the [Kaggle Nucleus Segmentation challenge](https://www.kaggle.com/c/data-science-bowl-2018).

# %%
from skimage.io import imread, imsave
from skimage.morphology import remove_small_holes

# %%
import uuid

# %%
str(uuid.uuid4())
# Out:
# '05359939-a4a2-4c60-b826-27a7fe08d432'

# %%
def convert_and_save(image, mask, output_dir):
    u_id = str(uuid.uuid4())
    if (not os.path.exists(os.path.join(output_dir, u_id))):
        os.mkdir(os.path.join(output_dir, u_id))
        os.mkdir(os.path.join(output_dir, u_id, 'masks'))
        os.mkdir(os.path.join(output_dir, u_id, 'images'))
                 
    for k in range(1, mask.max()+1):
        mask_u_id = str(uuid.uuid4())
        single_mask = (mask==k)
        mask_cleaned = remove_small_holes(single_mask)
        imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
    
    imsave(os.path.join(output_dir, u_id, 'images', u_id + '.tif'), image)

# %%
train_indices = ['34', '0', '36', '19', '10', '17', '18', '8', '25', '7', '37', '23', '29', '50', '42', '43', '32', '49', '33', '15', '31', '24', '9', '28', '5', '2', '39', '16', '22', '48', '44', '14', '6', '54', '45', '51', '41', '35']
val_indices = ['53', '21', '20', '13', '26', '46', '12', '52', '47', '27', '55', '1', '3', '4', '40', '38', '30']

# %%
input_dir = '../../../dl-course-2022/07_esc_3d_colonies/'

# %%
output_dir = '../../../tmp/tif_data/train/'

# %%
for i in train_indices:
    image = imread(os.path.join(input_dir, 'images', 'esc_siRDNA_' + i + '.tif'))
    mask = imread(os.path.join(input_dir, 'masks', 'esc_siRDNA_' + i + '.tif'))
    convert_and_save(image, mask, output_dir)
# Out:
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/ad7af566-c87c-46df-80bb-c4de904d6534/masks/ea66c66e-f35c-457e-afec-ae4cb75258ec.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/ad7af566-c87c-46df-80bb-c4de904d6534/masks/ea66c66e-f35c-457e-afec-ae4cb75258ec.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/ad7af566-c87c-46df-80bb-c4de904d6534/masks/ed80a40d-fdf3-4ef2-bf6b-dd81f7aa47cf.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/ad7af566-c87c-46df-80bb-c4de904d6534/masks/ed80a40d-fdf3-4ef2-bf6b-dd81f7aa47cf.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/ad7af566-c87c-46df-80bb-c4de904d6534/masks/dbef885a-a6ab-409d-bcb5-c2dcfbcb776e.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/ad7af566-c87c-46df-80bb-c4de904d6534/masks/dbef885a-a6ab-409d-bcb5-c2dcfbcb776e.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/ad7af566-c87c-46df-80bb-c4de904d6534/masks/c5dfac75-48c4-4a92-81d8-d80d5b070956.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/ad7af566-c87c-46df-80bb-c4de904d6534/masks/c5dfac75-48c4-4a92-81d8-d80d5b070956.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/ad7af566-c87c-46df-80bb-c4de904d6534/masks/b3bb4e0d-b850-483a-b29b-d72f20199d9a.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/ad7af566-c87c-46df-80bb-c4de904d6534/masks/b3bb4e0d-b850-483a-b29b-d72f20199d9a.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/ad7af566-c87c-46df-80bb-c4de904d6534/masks/cfc40d77-7b4e-4d56-a7f1-ef5354e255d9.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/ad7af566-c87c-46df-80bb-c4de904d6534/masks/cfc40d77-7b4e-4d56-a7f1-ef5354e255d9.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/ad7af566-c87c-46df-80bb-c4de904d6534/masks/3f3bf0ac-8ec0-40b3-b3d1-9f50ba2ba0d2.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/ad7af566-c87c-46df-80bb-c4de904d6534/masks/d50c4113-c5e2-4f9d-87f9-c4f756bee4e4.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/ad7af566-c87c-46df-80bb-c4de904d6534/masks/d50c4113-c5e2-4f9d-87f9-c4f756bee4e4.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/ad7af566-c87c-46df-80bb-c4de904d6534/masks/c0edcc21-73cf-46dd-8acd-ab4fa8bff497.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/ad7af566-c87c-46df-80bb-c4de904d6534/masks/c0edcc21-73cf-46dd-8acd-ab4fa8bff497.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/ad7af566-c87c-46df-80bb-c4de904d6534/masks/0e1bb098-a02a-451f-90c3-a44d7ec06d51.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/ad7af566-c87c-46df-80bb-c4de904d6534/masks/0e1bb098-a02a-451f-90c3-a44d7ec06d51.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/ad7af566-c87c-46df-80bb-c4de904d6534/masks/435f12d7-6577-45b9-a21f-0400345e93aa.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/ad7af566-c87c-46df-80bb-c4de904d6534/masks/435f12d7-6577-45b9-a21f-0400345e93aa.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/ad7af566-c87c-46df-80bb-c4de904d6534/masks/f0c3f376-c804-4c0b-a0ae-fc04b7e6c77e.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/ad7af566-c87c-46df-80bb-c4de904d6534/masks/f0c3f376-c804-4c0b-a0ae-fc04b7e6c77e.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/ad7af566-c87c-46df-80bb-c4de904d6534/masks/e2ffe487-e639-4ca5-8a79-969acc08c336.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/ad7af566-c87c-46df-80bb-c4de904d6534/masks/e2ffe487-e639-4ca5-8a79-969acc08c336.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/ad7af566-c87c-46df-80bb-c4de904d6534/masks/55ed8593-9fcd-499d-9b40-37562a31f8ff.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/ad7af566-c87c-46df-80bb-c4de904d6534/masks/55ed8593-9fcd-499d-9b40-37562a31f8ff.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/ad7af566-c87c-46df-80bb-c4de904d6534/masks/3c3f2337-1a96-48b7-8c61-457ffb0537fa.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/ad7af566-c87c-46df-80bb-c4de904d6534/masks/3c3f2337-1a96-48b7-8c61-457ffb0537fa.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/ad7af566-c87c-46df-80bb-c4de904d6534/masks/d7dcc4b2-ea94-4a38-84d8-9fa94fbf1ef1.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/ad7af566-c87c-46df-80bb-c4de904d6534/masks/d7dcc4b2-ea94-4a38-84d8-9fa94fbf1ef1.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/ad7af566-c87c-46df-80bb-c4de904d6534/masks/b1b19fbd-c009-4c49-ae3b-11a50c4062b1.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/ad7af566-c87c-46df-80bb-c4de904d6534/masks/b1b19fbd-c009-4c49-ae3b-11a50c4062b1.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/ad7af566-c87c-46df-80bb-c4de904d6534/masks/cb7b9984-d354-4b06-a7d5-62f0e92f8ec9.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/ad7af566-c87c-46df-80bb-c4de904d6534/masks/26751cc4-110c-439b-83a0-a185e910ce6e.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/ad7af566-c87c-46df-80bb-c4de904d6534/masks/26751cc4-110c-439b-83a0-a185e910ce6e.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:14: UserWarning: ../../../tmp/tif_data/train/ad7af566-c87c-46df-80bb-c4de904d6534/images/ad7af566-c87c-46df-80bb-c4de904d6534.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'images', u_id + '.tif'), image)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/99c0af72-61f9-4ddb-a448-91abbcb84461/masks/6869f97a-ffcc-445f-9c4b-6e9f5a26dfde.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/99c0af72-61f9-4ddb-a448-91abbcb84461/masks/6869f97a-ffcc-445f-9c4b-6e9f5a26dfde.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/99c0af72-61f9-4ddb-a448-91abbcb84461/masks/561ab2bf-26ec-412b-bfd9-d26188f50d25.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/99c0af72-61f9-4ddb-a448-91abbcb84461/masks/561ab2bf-26ec-412b-bfd9-d26188f50d25.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/99c0af72-61f9-4ddb-a448-91abbcb84461/masks/a5692d8c-05d2-4031-ab4d-f620cb5dcadb.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/99c0af72-61f9-4ddb-a448-91abbcb84461/masks/a5692d8c-05d2-4031-ab4d-f620cb5dcadb.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/99c0af72-61f9-4ddb-a448-91abbcb84461/masks/1c3a5457-5e46-46f2-ac2f-34061b02d014.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/99c0af72-61f9-4ddb-a448-91abbcb84461/masks/1c3a5457-5e46-46f2-ac2f-34061b02d014.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/99c0af72-61f9-4ddb-a448-91abbcb84461/masks/93b5fe9d-ceef-4cb7-bb0d-dcb6fc30d46f.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/99c0af72-61f9-4ddb-a448-91abbcb84461/masks/93b5fe9d-ceef-4cb7-bb0d-dcb6fc30d46f.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/99c0af72-61f9-4ddb-a448-91abbcb84461/masks/577ad0c2-0258-4eff-9d16-c390bb47174c.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/99c0af72-61f9-4ddb-a448-91abbcb84461/masks/577ad0c2-0258-4eff-9d16-c390bb47174c.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/99c0af72-61f9-4ddb-a448-91abbcb84461/masks/a231cd53-6511-47e3-9670-30d55cfa44c6.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/99c0af72-61f9-4ddb-a448-91abbcb84461/masks/a231cd53-6511-47e3-9670-30d55cfa44c6.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/99c0af72-61f9-4ddb-a448-91abbcb84461/masks/72f4e38b-771d-40dc-96d8-7c5ffd58f279.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/99c0af72-61f9-4ddb-a448-91abbcb84461/masks/72f4e38b-771d-40dc-96d8-7c5ffd58f279.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/99c0af72-61f9-4ddb-a448-91abbcb84461/masks/d22a7d03-49c6-4a1f-aee1-ea10170a2aa6.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/99c0af72-61f9-4ddb-a448-91abbcb84461/masks/23e875ab-2b34-42e9-9cbd-5be8b62e5f4c.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/99c0af72-61f9-4ddb-a448-91abbcb84461/masks/23e875ab-2b34-42e9-9cbd-5be8b62e5f4c.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:14: UserWarning: ../../../tmp/tif_data/train/99c0af72-61f9-4ddb-a448-91abbcb84461/images/99c0af72-61f9-4ddb-a448-91abbcb84461.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'images', u_id + '.tif'), image)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/541e8337-8b6e-408f-a712-549e56040bce/masks/507628a6-3b8e-4add-bcc1-62252e1ebaa6.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/541e8337-8b6e-408f-a712-549e56040bce/masks/507628a6-3b8e-4add-bcc1-62252e1ebaa6.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/541e8337-8b6e-408f-a712-549e56040bce/masks/6db38eea-7a2f-4ffc-83d9-036aa31a8bb9.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/541e8337-8b6e-408f-a712-549e56040bce/masks/6db38eea-7a2f-4ffc-83d9-036aa31a8bb9.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/541e8337-8b6e-408f-a712-549e56040bce/masks/02e64260-11d6-4562-97d0-af3369762ee6.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/541e8337-8b6e-408f-a712-549e56040bce/masks/02e64260-11d6-4562-97d0-af3369762ee6.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/541e8337-8b6e-408f-a712-549e56040bce/masks/4ae47f19-0ffe-44ba-8deb-145b6be5c577.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/541e8337-8b6e-408f-a712-549e56040bce/masks/4ae47f19-0ffe-44ba-8deb-145b6be5c577.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/541e8337-8b6e-408f-a712-549e56040bce/masks/bad7878d-5d7b-4bea-9eba-88a6a461222d.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/541e8337-8b6e-408f-a712-549e56040bce/masks/bad7878d-5d7b-4bea-9eba-88a6a461222d.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/541e8337-8b6e-408f-a712-549e56040bce/masks/bcb13e9c-fb9c-4a05-8a58-df07050aff2b.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/541e8337-8b6e-408f-a712-549e56040bce/masks/bcb13e9c-fb9c-4a05-8a58-df07050aff2b.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/541e8337-8b6e-408f-a712-549e56040bce/masks/36476736-1dd0-47bd-8815-6d0855dab473.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/541e8337-8b6e-408f-a712-549e56040bce/masks/36476736-1dd0-47bd-8815-6d0855dab473.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/541e8337-8b6e-408f-a712-549e56040bce/masks/0d4469d2-4572-41c5-8e0d-051ce7d9b564.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/541e8337-8b6e-408f-a712-549e56040bce/masks/0d4469d2-4572-41c5-8e0d-051ce7d9b564.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:14: UserWarning: ../../../tmp/tif_data/train/541e8337-8b6e-408f-a712-549e56040bce/images/541e8337-8b6e-408f-a712-549e56040bce.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'images', u_id + '.tif'), image)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/9985a17f-9ed9-4ecd-85aa-e1441a08e0ae/masks/20a79c1b-a950-4862-a6e7-eb0e1ca36319.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/9985a17f-9ed9-4ecd-85aa-e1441a08e0ae/masks/2bb93591-5eb2-4043-94a8-8a0c3a26dc8c.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/9985a17f-9ed9-4ecd-85aa-e1441a08e0ae/masks/d979c5e4-3d4b-4908-ac9c-8c62027a6a46.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/9985a17f-9ed9-4ecd-85aa-e1441a08e0ae/masks/d979c5e4-3d4b-4908-ac9c-8c62027a6a46.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/9985a17f-9ed9-4ecd-85aa-e1441a08e0ae/masks/1b019c17-2402-45cf-bae5-41867f16b3c5.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/9985a17f-9ed9-4ecd-85aa-e1441a08e0ae/masks/1b019c17-2402-45cf-bae5-41867f16b3c5.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/9985a17f-9ed9-4ecd-85aa-e1441a08e0ae/masks/ac6b796e-a7d6-4bad-81eb-d76b5d2905a0.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/9985a17f-9ed9-4ecd-85aa-e1441a08e0ae/masks/ac6b796e-a7d6-4bad-81eb-d76b5d2905a0.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/9985a17f-9ed9-4ecd-85aa-e1441a08e0ae/masks/6b38e52f-4543-440a-80fc-68eb1d2a9b52.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/9985a17f-9ed9-4ecd-85aa-e1441a08e0ae/masks/6b38e52f-4543-440a-80fc-68eb1d2a9b52.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/9985a17f-9ed9-4ecd-85aa-e1441a08e0ae/masks/ff27dbad-1a46-49f4-9eb9-7ba22f26f504.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/9985a17f-9ed9-4ecd-85aa-e1441a08e0ae/masks/ff27dbad-1a46-49f4-9eb9-7ba22f26f504.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/9985a17f-9ed9-4ecd-85aa-e1441a08e0ae/masks/48024011-d70b-4e58-9d55-46f34d59ded4.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/9985a17f-9ed9-4ecd-85aa-e1441a08e0ae/masks/48024011-d70b-4e58-9d55-46f34d59ded4.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:14: UserWarning: ../../../tmp/tif_data/train/9985a17f-9ed9-4ecd-85aa-e1441a08e0ae/images/9985a17f-9ed9-4ecd-85aa-e1441a08e0ae.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'images', u_id + '.tif'), image)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/7ae683c9-ee5a-4ebc-9033-f3ee56f03122/masks/0c5dba86-058a-4ce5-8fb8-f15a414b9879.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/7ae683c9-ee5a-4ebc-9033-f3ee56f03122/masks/0c5dba86-058a-4ce5-8fb8-f15a414b9879.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/7ae683c9-ee5a-4ebc-9033-f3ee56f03122/masks/0cd01f90-67da-4fb8-9e69-a519968113ee.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/7ae683c9-ee5a-4ebc-9033-f3ee56f03122/masks/0cd01f90-67da-4fb8-9e69-a519968113ee.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/7ae683c9-ee5a-4ebc-9033-f3ee56f03122/masks/dd29430a-01ad-47f9-9934-1f1800c1ec68.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/7ae683c9-ee5a-4ebc-9033-f3ee56f03122/masks/dd29430a-01ad-47f9-9934-1f1800c1ec68.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/7ae683c9-ee5a-4ebc-9033-f3ee56f03122/masks/e027053a-be8a-4460-bea2-ea9b2ac8d88b.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/7ae683c9-ee5a-4ebc-9033-f3ee56f03122/masks/e027053a-be8a-4460-bea2-ea9b2ac8d88b.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/7ae683c9-ee5a-4ebc-9033-f3ee56f03122/masks/84341ac5-cb5d-4fa8-a0d5-c43546da6f9f.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/7ae683c9-ee5a-4ebc-9033-f3ee56f03122/masks/84341ac5-cb5d-4fa8-a0d5-c43546da6f9f.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/7ae683c9-ee5a-4ebc-9033-f3ee56f03122/masks/46508510-7056-42be-a8fc-f5e7d91787fd.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/7ae683c9-ee5a-4ebc-9033-f3ee56f03122/masks/46508510-7056-42be-a8fc-f5e7d91787fd.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/7ae683c9-ee5a-4ebc-9033-f3ee56f03122/masks/73bbe216-9522-446b-8b0a-8524bf6a9fc4.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/7ae683c9-ee5a-4ebc-9033-f3ee56f03122/masks/73bbe216-9522-446b-8b0a-8524bf6a9fc4.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/7ae683c9-ee5a-4ebc-9033-f3ee56f03122/masks/26c75730-eb4b-4a90-9175-97dd4f166ea5.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/7ae683c9-ee5a-4ebc-9033-f3ee56f03122/masks/26c75730-eb4b-4a90-9175-97dd4f166ea5.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:14: UserWarning: ../../../tmp/tif_data/train/7ae683c9-ee5a-4ebc-9033-f3ee56f03122/images/7ae683c9-ee5a-4ebc-9033-f3ee56f03122.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'images', u_id + '.tif'), image)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/1c9238b1-1601-4433-b99d-4b4c2d6c8afe/masks/87624cc0-846c-46f4-9f56-22ff60e6139a.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/1c9238b1-1601-4433-b99d-4b4c2d6c8afe/masks/87624cc0-846c-46f4-9f56-22ff60e6139a.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/1c9238b1-1601-4433-b99d-4b4c2d6c8afe/masks/a9be201b-6c4d-4ffb-9da9-61724a23a817.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/1c9238b1-1601-4433-b99d-4b4c2d6c8afe/masks/a9be201b-6c4d-4ffb-9da9-61724a23a817.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/1c9238b1-1601-4433-b99d-4b4c2d6c8afe/masks/f56c681c-13db-413d-ad2a-6d3bc7906f48.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/1c9238b1-1601-4433-b99d-4b4c2d6c8afe/masks/f56c681c-13db-413d-ad2a-6d3bc7906f48.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/1c9238b1-1601-4433-b99d-4b4c2d6c8afe/masks/2b2077e8-96cd-4ee6-80a3-312d796fec66.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/1c9238b1-1601-4433-b99d-4b4c2d6c8afe/masks/2b2077e8-96cd-4ee6-80a3-312d796fec66.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/1c9238b1-1601-4433-b99d-4b4c2d6c8afe/masks/cbd1d7a8-ca85-4f93-a54e-3b68d032a75f.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/1c9238b1-1601-4433-b99d-4b4c2d6c8afe/masks/cbd1d7a8-ca85-4f93-a54e-3b68d032a75f.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/1c9238b1-1601-4433-b99d-4b4c2d6c8afe/masks/2472ed2a-015d-46c1-922f-f0aa35173c4c.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/1c9238b1-1601-4433-b99d-4b4c2d6c8afe/masks/2472ed2a-015d-46c1-922f-f0aa35173c4c.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/1c9238b1-1601-4433-b99d-4b4c2d6c8afe/masks/ab95e6ec-63b6-41d6-8556-a35ccebb2471.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/1c9238b1-1601-4433-b99d-4b4c2d6c8afe/masks/ab95e6ec-63b6-41d6-8556-a35ccebb2471.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/1c9238b1-1601-4433-b99d-4b4c2d6c8afe/masks/4714abec-f44f-4aac-9d10-318459ff4ef3.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/1c9238b1-1601-4433-b99d-4b4c2d6c8afe/masks/4714abec-f44f-4aac-9d10-318459ff4ef3.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:14: UserWarning: ../../../tmp/tif_data/train/1c9238b1-1601-4433-b99d-4b4c2d6c8afe/images/1c9238b1-1601-4433-b99d-4b4c2d6c8afe.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'images', u_id + '.tif'), image)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/31bc3c95-88d7-4db5-aabe-0cb825d455f7/masks/01c4303f-3c9b-4e8c-9b3b-94ca83a94701.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/31bc3c95-88d7-4db5-aabe-0cb825d455f7/masks/01c4303f-3c9b-4e8c-9b3b-94ca83a94701.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/31bc3c95-88d7-4db5-aabe-0cb825d455f7/masks/50b8e82e-58eb-42b2-888d-c0f19e55c172.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/31bc3c95-88d7-4db5-aabe-0cb825d455f7/masks/50b8e82e-58eb-42b2-888d-c0f19e55c172.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/31bc3c95-88d7-4db5-aabe-0cb825d455f7/masks/306fe186-de1a-4154-a99e-799829131673.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/31bc3c95-88d7-4db5-aabe-0cb825d455f7/masks/306fe186-de1a-4154-a99e-799829131673.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/31bc3c95-88d7-4db5-aabe-0cb825d455f7/masks/ea2e7c64-8e80-41c2-9f21-d3fa95258e85.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/31bc3c95-88d7-4db5-aabe-0cb825d455f7/masks/ea2e7c64-8e80-41c2-9f21-d3fa95258e85.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/31bc3c95-88d7-4db5-aabe-0cb825d455f7/masks/cd5f201b-211a-4340-80e0-bf103733eb1b.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/31bc3c95-88d7-4db5-aabe-0cb825d455f7/masks/cd5f201b-211a-4340-80e0-bf103733eb1b.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/31bc3c95-88d7-4db5-aabe-0cb825d455f7/masks/bcfb4244-284c-4248-a256-67b94d8dc116.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/31bc3c95-88d7-4db5-aabe-0cb825d455f7/masks/bcfb4244-284c-4248-a256-67b94d8dc116.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/31bc3c95-88d7-4db5-aabe-0cb825d455f7/masks/03866942-87a1-4405-98b8-4874851b7223.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/31bc3c95-88d7-4db5-aabe-0cb825d455f7/masks/03866942-87a1-4405-98b8-4874851b7223.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/31bc3c95-88d7-4db5-aabe-0cb825d455f7/masks/9445fcc5-5d86-47aa-a7af-81be35abadec.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/31bc3c95-88d7-4db5-aabe-0cb825d455f7/masks/35740e5f-5326-4932-aaf7-e4a83bcdb749.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/31bc3c95-88d7-4db5-aabe-0cb825d455f7/masks/35740e5f-5326-4932-aaf7-e4a83bcdb749.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/31bc3c95-88d7-4db5-aabe-0cb825d455f7/masks/04ccf237-c858-45b5-b048-551c709088bf.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/31bc3c95-88d7-4db5-aabe-0cb825d455f7/masks/04ccf237-c858-45b5-b048-551c709088bf.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:14: UserWarning: ../../../tmp/tif_data/train/31bc3c95-88d7-4db5-aabe-0cb825d455f7/images/31bc3c95-88d7-4db5-aabe-0cb825d455f7.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'images', u_id + '.tif'), image)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/351db681-7dcc-43cc-b2c4-e42d1db8dbb5/masks/579101ed-3232-4b13-ba41-012b5c2c0c88.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/351db681-7dcc-43cc-b2c4-e42d1db8dbb5/masks/579101ed-3232-4b13-ba41-012b5c2c0c88.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/351db681-7dcc-43cc-b2c4-e42d1db8dbb5/masks/68c5d0a0-619d-49f2-8138-18c6a0a4f8cc.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/351db681-7dcc-43cc-b2c4-e42d1db8dbb5/masks/68c5d0a0-619d-49f2-8138-18c6a0a4f8cc.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/351db681-7dcc-43cc-b2c4-e42d1db8dbb5/masks/c57c69cc-7b40-4304-b4e2-5c03729a911b.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/351db681-7dcc-43cc-b2c4-e42d1db8dbb5/masks/c57c69cc-7b40-4304-b4e2-5c03729a911b.tif is a low contrast image
# ...
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/7f50eaa6-fdbc-4267-8a93-0fd3e0a5439b/masks/395b3d82-43b3-4c3d-b3ec-819fd254bb34.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/7f50eaa6-fdbc-4267-8a93-0fd3e0a5439b/masks/f74ce72c-2249-428e-88a2-9d047e1643e1.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/7f50eaa6-fdbc-4267-8a93-0fd3e0a5439b/masks/f74ce72c-2249-428e-88a2-9d047e1643e1.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/7f50eaa6-fdbc-4267-8a93-0fd3e0a5439b/masks/3f61f290-25e1-4f0c-aaa7-534552ca0f8c.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/7f50eaa6-fdbc-4267-8a93-0fd3e0a5439b/masks/3f61f290-25e1-4f0c-aaa7-534552ca0f8c.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/7f50eaa6-fdbc-4267-8a93-0fd3e0a5439b/masks/4f6e585d-e42a-4a66-a517-7f9ab36766c8.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/7f50eaa6-fdbc-4267-8a93-0fd3e0a5439b/masks/4f6e585d-e42a-4a66-a517-7f9ab36766c8.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/7f50eaa6-fdbc-4267-8a93-0fd3e0a5439b/masks/8e293d95-2ebc-4430-b58b-a53cf6ea43bf.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/7f50eaa6-fdbc-4267-8a93-0fd3e0a5439b/masks/8928e5bd-8e9c-4a39-ab8d-1bb037939a9c.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/7f50eaa6-fdbc-4267-8a93-0fd3e0a5439b/masks/8928e5bd-8e9c-4a39-ab8d-1bb037939a9c.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/7f50eaa6-fdbc-4267-8a93-0fd3e0a5439b/masks/8a5fbb70-67bb-4305-a4e1-8f9600a1b6af.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/7f50eaa6-fdbc-4267-8a93-0fd3e0a5439b/masks/8a5fbb70-67bb-4305-a4e1-8f9600a1b6af.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/7f50eaa6-fdbc-4267-8a93-0fd3e0a5439b/masks/b2e4132f-ab28-4d44-9c8f-19b03dd158ad.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/7f50eaa6-fdbc-4267-8a93-0fd3e0a5439b/masks/b2e4132f-ab28-4d44-9c8f-19b03dd158ad.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/7f50eaa6-fdbc-4267-8a93-0fd3e0a5439b/masks/4023e850-acbf-4974-a128-d142555d0544.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/7f50eaa6-fdbc-4267-8a93-0fd3e0a5439b/masks/4023e850-acbf-4974-a128-d142555d0544.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/7f50eaa6-fdbc-4267-8a93-0fd3e0a5439b/masks/cc083fba-f969-48bc-bdac-77fb6e001156.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/7f50eaa6-fdbc-4267-8a93-0fd3e0a5439b/masks/cc083fba-f969-48bc-bdac-77fb6e001156.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/7f50eaa6-fdbc-4267-8a93-0fd3e0a5439b/masks/7f7adb08-c2f8-4639-a4de-635632165dcf.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/7f50eaa6-fdbc-4267-8a93-0fd3e0a5439b/masks/7f7adb08-c2f8-4639-a4de-635632165dcf.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/7f50eaa6-fdbc-4267-8a93-0fd3e0a5439b/masks/63614384-9189-48f7-b7d1-fef617cffc94.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/7f50eaa6-fdbc-4267-8a93-0fd3e0a5439b/masks/63614384-9189-48f7-b7d1-fef617cffc94.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/7f50eaa6-fdbc-4267-8a93-0fd3e0a5439b/masks/451ee7eb-40d6-44e9-8177-cb158d1d30ee.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/7f50eaa6-fdbc-4267-8a93-0fd3e0a5439b/masks/451ee7eb-40d6-44e9-8177-cb158d1d30ee.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/7f50eaa6-fdbc-4267-8a93-0fd3e0a5439b/masks/5297e165-2a48-4502-a27e-7f6266adfbea.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/7f50eaa6-fdbc-4267-8a93-0fd3e0a5439b/masks/5297e165-2a48-4502-a27e-7f6266adfbea.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/7f50eaa6-fdbc-4267-8a93-0fd3e0a5439b/masks/46a06c2c-5f8e-4f4f-a522-0823659628ee.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/7f50eaa6-fdbc-4267-8a93-0fd3e0a5439b/masks/46a06c2c-5f8e-4f4f-a522-0823659628ee.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/7f50eaa6-fdbc-4267-8a93-0fd3e0a5439b/masks/891a6fbb-4e32-4084-af79-243a0b0983b9.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/7f50eaa6-fdbc-4267-8a93-0fd3e0a5439b/masks/5358fb13-7c0f-4dcd-bb6c-55f784f2ab98.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/7f50eaa6-fdbc-4267-8a93-0fd3e0a5439b/masks/5358fb13-7c0f-4dcd-bb6c-55f784f2ab98.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:14: UserWarning: ../../../tmp/tif_data/train/7f50eaa6-fdbc-4267-8a93-0fd3e0a5439b/images/7f50eaa6-fdbc-4267-8a93-0fd3e0a5439b.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'images', u_id + '.tif'), image)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/1001c61a-a113-4e97-8e2a-201f98dde977/masks/208f6438-c903-4eaa-bba9-6f0e98f3bdb6.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/1001c61a-a113-4e97-8e2a-201f98dde977/masks/208f6438-c903-4eaa-bba9-6f0e98f3bdb6.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/1001c61a-a113-4e97-8e2a-201f98dde977/masks/54923ffa-96d5-4bc0-950f-a65d6c86c094.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/1001c61a-a113-4e97-8e2a-201f98dde977/masks/54923ffa-96d5-4bc0-950f-a65d6c86c094.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/1001c61a-a113-4e97-8e2a-201f98dde977/masks/685c7d65-aded-460c-9f6d-e4811258c725.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/1001c61a-a113-4e97-8e2a-201f98dde977/masks/685c7d65-aded-460c-9f6d-e4811258c725.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/1001c61a-a113-4e97-8e2a-201f98dde977/masks/b402d9a4-f824-427d-9f62-2a105f7f76b5.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/1001c61a-a113-4e97-8e2a-201f98dde977/masks/b402d9a4-f824-427d-9f62-2a105f7f76b5.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/1001c61a-a113-4e97-8e2a-201f98dde977/masks/59a53525-890d-4f54-82d8-7951fca1e8b6.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/1001c61a-a113-4e97-8e2a-201f98dde977/masks/59a53525-890d-4f54-82d8-7951fca1e8b6.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/1001c61a-a113-4e97-8e2a-201f98dde977/masks/0c8b064c-2a1c-4fb9-bc2a-ba13f90ae965.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/1001c61a-a113-4e97-8e2a-201f98dde977/masks/0c8b064c-2a1c-4fb9-bc2a-ba13f90ae965.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/1001c61a-a113-4e97-8e2a-201f98dde977/masks/e76e0a8e-b37f-4f54-bf50-120daa8795d1.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/1001c61a-a113-4e97-8e2a-201f98dde977/masks/e76e0a8e-b37f-4f54-bf50-120daa8795d1.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/1001c61a-a113-4e97-8e2a-201f98dde977/masks/345e2e34-5933-4149-b404-82d83ce8d30d.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/train/1001c61a-a113-4e97-8e2a-201f98dde977/masks/345e2e34-5933-4149-b404-82d83ce8d30d.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:14: UserWarning: ../../../tmp/tif_data/train/1001c61a-a113-4e97-8e2a-201f98dde977/images/1001c61a-a113-4e97-8e2a-201f98dde977.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'images', u_id + '.tif'), image)

# %%
output_dir = '../../../tmp/tif_data/val/'

# %%
for i in val_indices:
    image = imread(os.path.join(input_dir, 'images', 'esc_siRDNA_' + i + '.tif'))
    mask = imread(os.path.join(input_dir, 'masks', 'esc_siRDNA_' + i + '.tif'))
    convert_and_save(image, mask, output_dir)
# Out:
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/11a5c5ad-f5a1-417b-b260-eb095de19632/masks/5fbf76eb-d2f8-4232-a7d0-dcf3d336bffb.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/11a5c5ad-f5a1-417b-b260-eb095de19632/masks/5fbf76eb-d2f8-4232-a7d0-dcf3d336bffb.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/11a5c5ad-f5a1-417b-b260-eb095de19632/masks/97350816-9fa0-4739-866e-af82a4a55c2a.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/11a5c5ad-f5a1-417b-b260-eb095de19632/masks/97350816-9fa0-4739-866e-af82a4a55c2a.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/11a5c5ad-f5a1-417b-b260-eb095de19632/masks/e98e625a-9349-4868-83e8-ee4ed3e0fb1b.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/11a5c5ad-f5a1-417b-b260-eb095de19632/masks/e98e625a-9349-4868-83e8-ee4ed3e0fb1b.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/11a5c5ad-f5a1-417b-b260-eb095de19632/masks/733ae928-34e1-4b44-a593-38ca67e7b77c.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/11a5c5ad-f5a1-417b-b260-eb095de19632/masks/733ae928-34e1-4b44-a593-38ca67e7b77c.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/11a5c5ad-f5a1-417b-b260-eb095de19632/masks/dad773cf-d715-479d-b638-b56be009c00b.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/11a5c5ad-f5a1-417b-b260-eb095de19632/masks/dad773cf-d715-479d-b638-b56be009c00b.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/11a5c5ad-f5a1-417b-b260-eb095de19632/masks/e2bf778d-5e4d-4fb0-a850-d1de2851ed0c.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/11a5c5ad-f5a1-417b-b260-eb095de19632/masks/e2bf778d-5e4d-4fb0-a850-d1de2851ed0c.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/11a5c5ad-f5a1-417b-b260-eb095de19632/masks/7150ae3a-c035-4cd2-888c-ec9fc2a33eab.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/11a5c5ad-f5a1-417b-b260-eb095de19632/masks/7150ae3a-c035-4cd2-888c-ec9fc2a33eab.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/11a5c5ad-f5a1-417b-b260-eb095de19632/masks/3f68d418-3208-4b1b-af20-c557f5213194.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/11a5c5ad-f5a1-417b-b260-eb095de19632/masks/d6ad6df0-199b-4dc6-9e46-9767ed1cbaf0.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/11a5c5ad-f5a1-417b-b260-eb095de19632/masks/d6ad6df0-199b-4dc6-9e46-9767ed1cbaf0.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/11a5c5ad-f5a1-417b-b260-eb095de19632/masks/92d85719-f799-42e9-897c-7412cff1393e.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/11a5c5ad-f5a1-417b-b260-eb095de19632/masks/92d85719-f799-42e9-897c-7412cff1393e.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:14: UserWarning: ../../../tmp/tif_data/val/11a5c5ad-f5a1-417b-b260-eb095de19632/images/11a5c5ad-f5a1-417b-b260-eb095de19632.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'images', u_id + '.tif'), image)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/4cc61717-ff9d-4efe-9c30-c0705dc18422/masks/0359de1e-939b-405e-9f76-5d2a80533e5f.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/4cc61717-ff9d-4efe-9c30-c0705dc18422/masks/0359de1e-939b-405e-9f76-5d2a80533e5f.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/4cc61717-ff9d-4efe-9c30-c0705dc18422/masks/991adf76-ccd7-4a10-9e06-cfb439541a94.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/4cc61717-ff9d-4efe-9c30-c0705dc18422/masks/991adf76-ccd7-4a10-9e06-cfb439541a94.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/4cc61717-ff9d-4efe-9c30-c0705dc18422/masks/cd246397-aa3b-43d8-b2f7-15b2a7031c0b.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/4cc61717-ff9d-4efe-9c30-c0705dc18422/masks/cd246397-aa3b-43d8-b2f7-15b2a7031c0b.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/4cc61717-ff9d-4efe-9c30-c0705dc18422/masks/415586ac-6ac8-455f-87ab-efc4999f9a73.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/4cc61717-ff9d-4efe-9c30-c0705dc18422/masks/415586ac-6ac8-455f-87ab-efc4999f9a73.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/4cc61717-ff9d-4efe-9c30-c0705dc18422/masks/36a2ce25-c558-4d2c-a81d-131fb9644b2e.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/4cc61717-ff9d-4efe-9c30-c0705dc18422/masks/36a2ce25-c558-4d2c-a81d-131fb9644b2e.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/4cc61717-ff9d-4efe-9c30-c0705dc18422/masks/9f911fb8-3647-4e55-acee-d30eaa2e5699.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/4cc61717-ff9d-4efe-9c30-c0705dc18422/masks/9f911fb8-3647-4e55-acee-d30eaa2e5699.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/4cc61717-ff9d-4efe-9c30-c0705dc18422/masks/3447c4af-0f58-4421-a9e9-56d9743f7784.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/4cc61717-ff9d-4efe-9c30-c0705dc18422/masks/870c799a-dc3f-4dd7-8243-f8fb54d65497.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/4cc61717-ff9d-4efe-9c30-c0705dc18422/masks/870c799a-dc3f-4dd7-8243-f8fb54d65497.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/4cc61717-ff9d-4efe-9c30-c0705dc18422/masks/a9a4af5a-4a93-424e-ae9e-6fdd73dc7da8.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/4cc61717-ff9d-4efe-9c30-c0705dc18422/masks/a9a4af5a-4a93-424e-ae9e-6fdd73dc7da8.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/4cc61717-ff9d-4efe-9c30-c0705dc18422/masks/fa706162-5e8f-441e-8f23-f9763c4b6d2e.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/4cc61717-ff9d-4efe-9c30-c0705dc18422/masks/fa706162-5e8f-441e-8f23-f9763c4b6d2e.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/4cc61717-ff9d-4efe-9c30-c0705dc18422/masks/636cef90-eec2-41de-b857-e6450bcf59cd.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/4cc61717-ff9d-4efe-9c30-c0705dc18422/masks/636cef90-eec2-41de-b857-e6450bcf59cd.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/4cc61717-ff9d-4efe-9c30-c0705dc18422/masks/79a39742-13f4-4b17-afae-7ded63ded2d3.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/4cc61717-ff9d-4efe-9c30-c0705dc18422/masks/79a39742-13f4-4b17-afae-7ded63ded2d3.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/4cc61717-ff9d-4efe-9c30-c0705dc18422/masks/56e902b4-5137-446d-95f5-6bc578e234f6.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/4cc61717-ff9d-4efe-9c30-c0705dc18422/masks/56e902b4-5137-446d-95f5-6bc578e234f6.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/4cc61717-ff9d-4efe-9c30-c0705dc18422/masks/fbcc014d-7724-4fd7-b75f-89c1a1e4aaf3.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/4cc61717-ff9d-4efe-9c30-c0705dc18422/masks/fbcc014d-7724-4fd7-b75f-89c1a1e4aaf3.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/4cc61717-ff9d-4efe-9c30-c0705dc18422/masks/6cba2ab1-2104-4afe-8dda-84d6d8727499.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/4cc61717-ff9d-4efe-9c30-c0705dc18422/masks/6cba2ab1-2104-4afe-8dda-84d6d8727499.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/4cc61717-ff9d-4efe-9c30-c0705dc18422/masks/808c04de-fd43-4e69-954d-e6d0e28e54d7.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/4cc61717-ff9d-4efe-9c30-c0705dc18422/masks/808c04de-fd43-4e69-954d-e6d0e28e54d7.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/4cc61717-ff9d-4efe-9c30-c0705dc18422/masks/46cf6bbc-afd0-4f3c-b0d5-af6c83976659.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/4cc61717-ff9d-4efe-9c30-c0705dc18422/masks/46cf6bbc-afd0-4f3c-b0d5-af6c83976659.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/4cc61717-ff9d-4efe-9c30-c0705dc18422/masks/d93ccb0e-f1a6-4b7d-9245-d10dd8c1c823.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/4cc61717-ff9d-4efe-9c30-c0705dc18422/masks/214f581c-5a52-4cf4-acdc-fd12166b8a1d.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/4cc61717-ff9d-4efe-9c30-c0705dc18422/masks/214f581c-5a52-4cf4-acdc-fd12166b8a1d.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:14: UserWarning: ../../../tmp/tif_data/val/4cc61717-ff9d-4efe-9c30-c0705dc18422/images/4cc61717-ff9d-4efe-9c30-c0705dc18422.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'images', u_id + '.tif'), image)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/e591c47c-c286-4ef1-96d1-e3a0c166ed7a/masks/0e0f0977-e885-4f79-aa42-e6a334e9fd9e.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/e591c47c-c286-4ef1-96d1-e3a0c166ed7a/masks/0e0f0977-e885-4f79-aa42-e6a334e9fd9e.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/e591c47c-c286-4ef1-96d1-e3a0c166ed7a/masks/3ca6a421-c84c-425b-96af-9b9b87ecf475.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/e591c47c-c286-4ef1-96d1-e3a0c166ed7a/masks/da41cb4e-6b1e-4263-95c1-49b36934e7e6.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/e591c47c-c286-4ef1-96d1-e3a0c166ed7a/masks/da41cb4e-6b1e-4263-95c1-49b36934e7e6.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/e591c47c-c286-4ef1-96d1-e3a0c166ed7a/masks/b1ef7702-b071-465b-9142-eca621d4cccd.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/e591c47c-c286-4ef1-96d1-e3a0c166ed7a/masks/b1ef7702-b071-465b-9142-eca621d4cccd.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/e591c47c-c286-4ef1-96d1-e3a0c166ed7a/masks/087dd15d-4c51-4fc8-9a12-ed3e629760e9.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/e591c47c-c286-4ef1-96d1-e3a0c166ed7a/masks/087dd15d-4c51-4fc8-9a12-ed3e629760e9.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/e591c47c-c286-4ef1-96d1-e3a0c166ed7a/masks/29c269be-3d56-4e91-81b9-e6565e2dc870.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/e591c47c-c286-4ef1-96d1-e3a0c166ed7a/masks/29c269be-3d56-4e91-81b9-e6565e2dc870.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/e591c47c-c286-4ef1-96d1-e3a0c166ed7a/masks/7408dc39-b509-4ef1-ae76-55a81f2fb1b5.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/e591c47c-c286-4ef1-96d1-e3a0c166ed7a/masks/d997e702-698d-49a1-b523-0fdd2a576a02.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/e591c47c-c286-4ef1-96d1-e3a0c166ed7a/masks/d997e702-698d-49a1-b523-0fdd2a576a02.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/e591c47c-c286-4ef1-96d1-e3a0c166ed7a/masks/b584070d-1c80-4768-aaea-51ca3e9b14d2.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/e591c47c-c286-4ef1-96d1-e3a0c166ed7a/masks/b584070d-1c80-4768-aaea-51ca3e9b14d2.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:14: UserWarning: ../../../tmp/tif_data/val/e591c47c-c286-4ef1-96d1-e3a0c166ed7a/images/e591c47c-c286-4ef1-96d1-e3a0c166ed7a.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'images', u_id + '.tif'), image)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/6bab8bb0-3966-46e3-a3a9-8a20be9120ff/masks/f960915b-f06b-4516-abc2-3ec3e43c43de.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/6bab8bb0-3966-46e3-a3a9-8a20be9120ff/masks/fa53eebb-8c25-4538-873d-f23d521cb52a.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/6bab8bb0-3966-46e3-a3a9-8a20be9120ff/masks/4650282f-5084-4d4c-9c65-13d07a9ba134.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/6bab8bb0-3966-46e3-a3a9-8a20be9120ff/masks/4650282f-5084-4d4c-9c65-13d07a9ba134.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/6bab8bb0-3966-46e3-a3a9-8a20be9120ff/masks/9f780bbb-3419-4300-adcf-7787a67f621b.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/6bab8bb0-3966-46e3-a3a9-8a20be9120ff/masks/9f780bbb-3419-4300-adcf-7787a67f621b.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/6bab8bb0-3966-46e3-a3a9-8a20be9120ff/masks/6a64049a-0cb3-447c-a463-cbe16faf8bd3.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/6bab8bb0-3966-46e3-a3a9-8a20be9120ff/masks/6a64049a-0cb3-447c-a463-cbe16faf8bd3.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/6bab8bb0-3966-46e3-a3a9-8a20be9120ff/masks/e9c98351-17b9-482f-995a-6562a171dfa4.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/6bab8bb0-3966-46e3-a3a9-8a20be9120ff/masks/e9c98351-17b9-482f-995a-6562a171dfa4.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/6bab8bb0-3966-46e3-a3a9-8a20be9120ff/masks/ddcb97b1-392b-46fc-b36c-6b836577f27a.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/6bab8bb0-3966-46e3-a3a9-8a20be9120ff/masks/ddcb97b1-392b-46fc-b36c-6b836577f27a.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/6bab8bb0-3966-46e3-a3a9-8a20be9120ff/masks/35f3bf53-7b66-4132-adba-d878373a9481.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/6bab8bb0-3966-46e3-a3a9-8a20be9120ff/masks/35f3bf53-7b66-4132-adba-d878373a9481.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:14: UserWarning: ../../../tmp/tif_data/val/6bab8bb0-3966-46e3-a3a9-8a20be9120ff/images/6bab8bb0-3966-46e3-a3a9-8a20be9120ff.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'images', u_id + '.tif'), image)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/5250b029-021a-4772-96d3-cebaebe65849/masks/f584e242-c76e-4b7a-9999-58e0feb0feb8.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/5250b029-021a-4772-96d3-cebaebe65849/masks/f584e242-c76e-4b7a-9999-58e0feb0feb8.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/5250b029-021a-4772-96d3-cebaebe65849/masks/7c6f08af-69c4-4091-98dd-8fc8f24532ea.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/5250b029-021a-4772-96d3-cebaebe65849/masks/7c6f08af-69c4-4091-98dd-8fc8f24532ea.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/5250b029-021a-4772-96d3-cebaebe65849/masks/ab151093-48de-433b-a0ca-c556ab423cdf.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/5250b029-021a-4772-96d3-cebaebe65849/masks/ab151093-48de-433b-a0ca-c556ab423cdf.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/5250b029-021a-4772-96d3-cebaebe65849/masks/594edc71-6b01-455b-a79d-27e3253f82e9.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/5250b029-021a-4772-96d3-cebaebe65849/masks/594edc71-6b01-455b-a79d-27e3253f82e9.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/5250b029-021a-4772-96d3-cebaebe65849/masks/6aec9187-d6ed-42af-92f1-0def5b5f5de5.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/5250b029-021a-4772-96d3-cebaebe65849/masks/6aec9187-d6ed-42af-92f1-0def5b5f5de5.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/5250b029-021a-4772-96d3-cebaebe65849/masks/e453d41e-aa5a-4eb4-97fc-e94119689c9b.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/5250b029-021a-4772-96d3-cebaebe65849/masks/e453d41e-aa5a-4eb4-97fc-e94119689c9b.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/5250b029-021a-4772-96d3-cebaebe65849/masks/c3390847-89e5-4ec8-8cf9-8b58b0a16506.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/5250b029-021a-4772-96d3-cebaebe65849/masks/c3390847-89e5-4ec8-8cf9-8b58b0a16506.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/5250b029-021a-4772-96d3-cebaebe65849/masks/f7ec23d1-4773-47a6-85b4-713104a283c1.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/5250b029-021a-4772-96d3-cebaebe65849/masks/f7ec23d1-4773-47a6-85b4-713104a283c1.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/5250b029-021a-4772-96d3-cebaebe65849/masks/71aa226e-597e-4072-908a-fd68ca338569.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/5250b029-021a-4772-96d3-cebaebe65849/masks/7bd58c3c-d8c3-4218-a7f6-b105f62afca9.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/5250b029-021a-4772-96d3-cebaebe65849/masks/7bd58c3c-d8c3-4218-a7f6-b105f62afca9.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:14: UserWarning: ../../../tmp/tif_data/val/5250b029-021a-4772-96d3-cebaebe65849/images/5250b029-021a-4772-96d3-cebaebe65849.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'images', u_id + '.tif'), image)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/5ee795e4-26b0-4903-bce7-9434a5ed87e9/masks/be471355-0741-475b-aae6-77f340a2103a.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/5ee795e4-26b0-4903-bce7-9434a5ed87e9/masks/be471355-0741-475b-aae6-77f340a2103a.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/5ee795e4-26b0-4903-bce7-9434a5ed87e9/masks/601552de-ee0c-4f39-88e1-f4e4bda8d37c.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/5ee795e4-26b0-4903-bce7-9434a5ed87e9/masks/601552de-ee0c-4f39-88e1-f4e4bda8d37c.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/5ee795e4-26b0-4903-bce7-9434a5ed87e9/masks/2ac3c686-6171-4d67-a3c9-076e4501663c.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/5ee795e4-26b0-4903-bce7-9434a5ed87e9/masks/2ac3c686-6171-4d67-a3c9-076e4501663c.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/5ee795e4-26b0-4903-bce7-9434a5ed87e9/masks/c0909591-d012-4aeb-9ff1-1e3a4f4a913b.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/5ee795e4-26b0-4903-bce7-9434a5ed87e9/masks/c0909591-d012-4aeb-9ff1-1e3a4f4a913b.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/5ee795e4-26b0-4903-bce7-9434a5ed87e9/masks/880b5734-4127-4dce-98ad-0a0336947a9f.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/5ee795e4-26b0-4903-bce7-9434a5ed87e9/masks/880b5734-4127-4dce-98ad-0a0336947a9f.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/5ee795e4-26b0-4903-bce7-9434a5ed87e9/masks/cf9812fd-193f-424c-9aef-d2debfaae29a.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/5ee795e4-26b0-4903-bce7-9434a5ed87e9/masks/cf9812fd-193f-424c-9aef-d2debfaae29a.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/5ee795e4-26b0-4903-bce7-9434a5ed87e9/masks/1fca0385-1d6f-4df7-b46e-f41228d6c8a2.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/5ee795e4-26b0-4903-bce7-9434a5ed87e9/masks/1fca0385-1d6f-4df7-b46e-f41228d6c8a2.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/5ee795e4-26b0-4903-bce7-9434a5ed87e9/masks/4b8952b3-d6d8-44f3-9a31-e7204fd9f2d7.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/5ee795e4-26b0-4903-bce7-9434a5ed87e9/masks/ebdd34a8-363c-4e46-a42a-e4ef86151669.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/5ee795e4-26b0-4903-bce7-9434a5ed87e9/masks/ebdd34a8-363c-4e46-a42a-e4ef86151669.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/5ee795e4-26b0-4903-bce7-9434a5ed87e9/masks/a5f90f46-9bc7-4ec3-a92c-69c11ff26a56.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/5ee795e4-26b0-4903-bce7-9434a5ed87e9/masks/a5f90f46-9bc7-4ec3-a92c-69c11ff26a56.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:14: UserWarning: ../../../tmp/tif_data/val/5ee795e4-26b0-4903-bce7-9434a5ed87e9/images/5ee795e4-26b0-4903-bce7-9434a5ed87e9.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'images', u_id + '.tif'), image)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/31f3d99a-3c39-4a55-9068-b50f3caf7584/masks/d19b4e1b-8ec0-4bf5-9116-03a34246d190.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/31f3d99a-3c39-4a55-9068-b50f3caf7584/masks/d19b4e1b-8ec0-4bf5-9116-03a34246d190.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/31f3d99a-3c39-4a55-9068-b50f3caf7584/masks/2c124cfa-bb65-45e0-b580-77eb1faa357c.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/31f3d99a-3c39-4a55-9068-b50f3caf7584/masks/2c124cfa-bb65-45e0-b580-77eb1faa357c.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/31f3d99a-3c39-4a55-9068-b50f3caf7584/masks/c1d9c76b-b210-416e-a8ef-0d796f103015.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/31f3d99a-3c39-4a55-9068-b50f3caf7584/masks/c1d9c76b-b210-416e-a8ef-0d796f103015.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/31f3d99a-3c39-4a55-9068-b50f3caf7584/masks/2d7d2fb7-c58d-45c4-9541-173d2f05bb8b.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/31f3d99a-3c39-4a55-9068-b50f3caf7584/masks/2d7d2fb7-c58d-45c4-9541-173d2f05bb8b.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/31f3d99a-3c39-4a55-9068-b50f3caf7584/masks/7df8f920-44a0-4eba-bbad-6643d319b6a2.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/31f3d99a-3c39-4a55-9068-b50f3caf7584/masks/7df8f920-44a0-4eba-bbad-6643d319b6a2.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/31f3d99a-3c39-4a55-9068-b50f3caf7584/masks/df083498-c789-4ecb-8384-63b66e96bc7e.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/31f3d99a-3c39-4a55-9068-b50f3caf7584/masks/df083498-c789-4ecb-8384-63b66e96bc7e.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/31f3d99a-3c39-4a55-9068-b50f3caf7584/masks/7ad53067-b7a7-400b-95eb-fb2835e686c8.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/31f3d99a-3c39-4a55-9068-b50f3caf7584/masks/7ad53067-b7a7-400b-95eb-fb2835e686c8.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/31f3d99a-3c39-4a55-9068-b50f3caf7584/masks/616bf755-1799-4f80-97bb-7829243056e9.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/31f3d99a-3c39-4a55-9068-b50f3caf7584/masks/616bf755-1799-4f80-97bb-7829243056e9.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/31f3d99a-3c39-4a55-9068-b50f3caf7584/masks/8a1d47b3-268f-451a-9f3d-2610aca8f29d.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/31f3d99a-3c39-4a55-9068-b50f3caf7584/masks/8a1d47b3-268f-451a-9f3d-2610aca8f29d.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:14: UserWarning: ../../../tmp/tif_data/val/31f3d99a-3c39-4a55-9068-b50f3caf7584/images/31f3d99a-3c39-4a55-9068-b50f3caf7584.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'images', u_id + '.tif'), image)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/0186f4fd-3015-4cd0-9b18-c877a431bd7e/masks/f2e1eb85-3b6d-44b9-be1e-c07eef9fca81.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# ...
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/779c550a-1869-4759-955c-f75f1b5aa870/masks/910b9a3b-8f58-4fbf-b23e-ac4b520f406f.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/779c550a-1869-4759-955c-f75f1b5aa870/masks/97e2d371-17cc-4ce5-aca5-f349fd31e1c1.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/779c550a-1869-4759-955c-f75f1b5aa870/masks/97e2d371-17cc-4ce5-aca5-f349fd31e1c1.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/779c550a-1869-4759-955c-f75f1b5aa870/masks/62685d29-f665-4394-af72-6e7952052db1.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/779c550a-1869-4759-955c-f75f1b5aa870/masks/62685d29-f665-4394-af72-6e7952052db1.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/779c550a-1869-4759-955c-f75f1b5aa870/masks/414a0d7c-61cf-4053-bf9c-7904a59bfe54.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/779c550a-1869-4759-955c-f75f1b5aa870/masks/414a0d7c-61cf-4053-bf9c-7904a59bfe54.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/779c550a-1869-4759-955c-f75f1b5aa870/masks/ceb336f7-43ba-47d3-bb09-901796299dc8.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/779c550a-1869-4759-955c-f75f1b5aa870/masks/ceb336f7-43ba-47d3-bb09-901796299dc8.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/779c550a-1869-4759-955c-f75f1b5aa870/masks/540f53c5-3fdb-4338-b4cd-8195c56d53f3.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/779c550a-1869-4759-955c-f75f1b5aa870/masks/722c962c-a453-4d6b-afb1-ed1040108f47.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/779c550a-1869-4759-955c-f75f1b5aa870/masks/722c962c-a453-4d6b-afb1-ed1040108f47.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/779c550a-1869-4759-955c-f75f1b5aa870/masks/0ee93191-39a6-4629-b96e-7d00fb2f319c.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/779c550a-1869-4759-955c-f75f1b5aa870/masks/0ee93191-39a6-4629-b96e-7d00fb2f319c.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/779c550a-1869-4759-955c-f75f1b5aa870/masks/f537749b-04a9-4b6c-8bd7-edca5a48b322.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/779c550a-1869-4759-955c-f75f1b5aa870/masks/f537749b-04a9-4b6c-8bd7-edca5a48b322.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/779c550a-1869-4759-955c-f75f1b5aa870/masks/945eab57-daa9-4198-8c80-55a61e7423a8.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/779c550a-1869-4759-955c-f75f1b5aa870/masks/945eab57-daa9-4198-8c80-55a61e7423a8.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/779c550a-1869-4759-955c-f75f1b5aa870/masks/0426b434-9bd7-4f26-a695-09878c7506d3.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/779c550a-1869-4759-955c-f75f1b5aa870/masks/0426b434-9bd7-4f26-a695-09878c7506d3.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/779c550a-1869-4759-955c-f75f1b5aa870/masks/e7dd2e89-8fca-4c8e-b27e-986cc0eff471.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/779c550a-1869-4759-955c-f75f1b5aa870/masks/e7dd2e89-8fca-4c8e-b27e-986cc0eff471.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/779c550a-1869-4759-955c-f75f1b5aa870/masks/625c0a33-7888-4271-91e6-5a173084b4c3.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/779c550a-1869-4759-955c-f75f1b5aa870/masks/625c0a33-7888-4271-91e6-5a173084b4c3.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/779c550a-1869-4759-955c-f75f1b5aa870/masks/54b3ee76-4b19-46fe-baa5-ec26688f5d7b.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/779c550a-1869-4759-955c-f75f1b5aa870/masks/54b3ee76-4b19-46fe-baa5-ec26688f5d7b.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/779c550a-1869-4759-955c-f75f1b5aa870/masks/d8faf19d-a453-4125-9b38-a4a186ba0725.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/779c550a-1869-4759-955c-f75f1b5aa870/masks/d8faf19d-a453-4125-9b38-a4a186ba0725.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/779c550a-1869-4759-955c-f75f1b5aa870/masks/10196da5-5606-4d75-9f66-f4208ec96570.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/779c550a-1869-4759-955c-f75f1b5aa870/masks/10196da5-5606-4d75-9f66-f4208ec96570.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/779c550a-1869-4759-955c-f75f1b5aa870/masks/ea590afa-fcfa-4b2b-9168-9b8efe9297ea.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/779c550a-1869-4759-955c-f75f1b5aa870/masks/50eab933-adf0-4da4-a68c-9ed202d1969d.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/779c550a-1869-4759-955c-f75f1b5aa870/masks/50eab933-adf0-4da4-a68c-9ed202d1969d.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:14: UserWarning: ../../../tmp/tif_data/val/779c550a-1869-4759-955c-f75f1b5aa870/images/779c550a-1869-4759-955c-f75f1b5aa870.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'images', u_id + '.tif'), image)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/a5ce21e3-4f35-48be-bfc6-51427497638c/masks/79f82ca2-2b35-4ca8-b9b4-5873d5647019.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/a5ce21e3-4f35-48be-bfc6-51427497638c/masks/b24d3a68-9236-44e3-b698-da4bd04da7f4.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/a5ce21e3-4f35-48be-bfc6-51427497638c/masks/7899b438-80c7-4c0d-960b-c70a0cdda040.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/a5ce21e3-4f35-48be-bfc6-51427497638c/masks/7899b438-80c7-4c0d-960b-c70a0cdda040.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/a5ce21e3-4f35-48be-bfc6-51427497638c/masks/eef9a424-810f-4e19-8792-5f06411b1e97.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/a5ce21e3-4f35-48be-bfc6-51427497638c/masks/eef9a424-810f-4e19-8792-5f06411b1e97.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/a5ce21e3-4f35-48be-bfc6-51427497638c/masks/9effec82-439f-4094-877b-23e373b8ae4b.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/a5ce21e3-4f35-48be-bfc6-51427497638c/masks/9effec82-439f-4094-877b-23e373b8ae4b.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/a5ce21e3-4f35-48be-bfc6-51427497638c/masks/278b9594-a93b-44d5-9937-1f8826e8df27.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/a5ce21e3-4f35-48be-bfc6-51427497638c/masks/278b9594-a93b-44d5-9937-1f8826e8df27.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/a5ce21e3-4f35-48be-bfc6-51427497638c/masks/bf0acace-178d-4ef2-8a95-a3fe817274be.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/a5ce21e3-4f35-48be-bfc6-51427497638c/masks/bf0acace-178d-4ef2-8a95-a3fe817274be.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/a5ce21e3-4f35-48be-bfc6-51427497638c/masks/49ee8eaa-7824-4559-bf5a-1ddb3ffeaca9.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:12: UserWarning: ../../../tmp/tif_data/val/a5ce21e3-4f35-48be-bfc6-51427497638c/masks/49ee8eaa-7824-4559-bf5a-1ddb3ffeaca9.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'masks', mask_u_id + '.tif'), mask_cleaned)
# /tmp/ipykernel_22385/2674854036.py:14: UserWarning: ../../../tmp/tif_data/val/a5ce21e3-4f35-48be-bfc6-51427497638c/images/a5ce21e3-4f35-48be-bfc6-51427497638c.tif is a low contrast image
#   imsave(os.path.join(output_dir, u_id, 'images', u_id + '.tif'), image)

# %% [markdown]
# ## The libraries

# %%
# %matplotlib inline
# %load_ext tensorboard
import os
import imageio
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
from scipy.ndimage import binary_erosion
import torch
from torch.utils.data import Dataset, DataLoader
from torch.utils.tensorboard import SummaryWriter
import torch.nn as nn
from torch.nn import functional as F
from torchvision import transforms
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %% [markdown]
# Split tiffs into training and validation data sets. Indices of train / val are same as used in trraining of 3dunet (Wolny et al.).

# %% [markdown]
# ## Data loading and preprocessing
#
# We first download amd explore the data.

# %% [markdown]
# Now make sure that the data was downloaded and extracted correctly. If everything went fine, you should have folders `nuclei_train_data` and `nuclei_val_data` in your working directory:

# %%
def show_one_image(image_path):
  image = imageio.imread(image_path)
  plt.imshow(image)

# %% [markdown]
# The first step to training a network in pytorch is to write a dataset - a class that will fetch the training samples. You can find a dataset class for the nucleus data below.
# You can find more information about datasets in pytorch [here](https://pytorch.org/docs/stable/data.html?highlight=dataset#torch.utils.data.Dataset) and [here](https://pytorch.org/tutorials/beginner/data_loading_tutorial.html#dataset-class).
#
# The main idea: any Dataset class should have two methods: `len` that returns the dataset length (the number of elements) and `getitem` that, given an index, returns input (image) and target (ground truth).
#
# Please have a look at the dataset implementation:

# %%
# any PyTorch dataset class should inherit the initial torch.utils.data.Dataset
class NucleiDataset(Dataset):
    """ A PyTorch dataset to load cell images and nuclei masks """
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir  # the directory with all the training samples
        self.samples = os.listdir(root_dir) # list the samples
        self.transform = transform    # transformations to apply to both inputs and targets
        #  transformations to apply just to inputs
        self.inp_transforms = transforms.Compose([transforms.Grayscale(), # some of the images are RGB
                                                  transforms.ToTensor(),
                                                  transforms.Normalize([0.5], [0.5])])
        # transformations to apply just to targets
        self.mask_transforms = transforms.ToTensor()

    # get the total number of samples
    def __len__(self):
        return len(self.samples)

    # fetch the training sample given its index
    def __getitem__(self, idx):
        img_path = os.path.join(self.root_dir, self.samples[idx],
                                'images', self.samples[idx]+'.tiff')
        # we'll be using Pillow library for reading files
        # since many torchvision transforms operate on PIL images 
        image = Image.open(img_path)
        image = self.inp_transforms(image)
        masks_dir = os.path.join(self.root_dir, self.samples[idx], 'masks')
        # masks directory has multiple images - one mask per nucleus
        masks_list = os.listdir(masks_dir)
        # create an empty array
        mask = torch.zeros_like(image)
        # iterate through the images to sum them up to one mask
        for mask_name in masks_list:
            one_nuclei_mask = Image.open(os.path.join(masks_dir, mask_name))
            # erode the image by one pixel
            # TASK: guess why is this done?
            one_nuclei_mask = binary_erosion(one_nuclei_mask)
            one_nuclei_mask = self.mask_transforms(one_nuclei_mask)
            # add this nucleus to the mask
            mask += one_nuclei_mask
        if self.transform is not None:
            image, mask = self.transform([image, mask])
        return image, mask

# %% [markdown]
# Now let's load the dataset and visualize it with a simple function:

# %%
TRAIN_DATA_PATH = '../../../tmp/train'
train_data = NucleiDataset(TRAIN_DATA_PATH)

# %%
def show_random_dataset_image(dataset):
    idx = np.random.randint(0, len(dataset))    # take a random sample
    img, mask = dataset[idx]                    # get the image and the nuclei masks
    f, axarr = plt.subplots(1, 2)               # make two plots on one figure
    axarr[0].imshow(img[0])                     # show the image
    axarr[1].imshow(mask[0])                    # show the masks
    _ = [ax.axis('off') for ax in axarr]        # remove the axes
    print('Image size is %s' % {img[0].shape})
    plt.show()

# %%
show_random_dataset_image(train_data)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_22385/2275100939.py in <module>
# ----> 1 show_random_dataset_image(train_data)
#
# /tmp/ipykernel_22385/2032164554.py in show_random_dataset_image(dataset)
#       1 def show_random_dataset_image(dataset):
#       2     idx = np.random.randint(0, len(dataset))    # take a random sample
# ----> 3     img, mask = dataset[idx]                    # get the image and the nuclei masks
#       4     f, axarr = plt.subplots(1, 2)               # make two plots on one figure
#       5     axarr[0].imshow(img[0])                     # show the image
#
# /tmp/ipykernel_22385/842476890.py in __getitem__(self, idx)
#      23         # we'll be using Pillow library for reading files
#      24         # since many torchvision transforms operate on PIL images
# ---> 25         image = Image.open(img_path)
#      26         image = self.inp_transforms(image)
#      27         masks_dir = os.path.join(self.root_dir, 'masks', self.samples[idx], '.tif')
#
# /opt/conda/envs/dl-pytorch/lib/python3.8/site-packages/PIL/Image.py in open(fp, mode, formats)
#    2973
#    2974     if filename:
# -> 2975         fp = builtins.open(filename, "rb")
#    2976         exclusive_fp = True
#    2977
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../../tmp/tif_data/train/images/masks.tif'

# %% [markdown]
# If you visualized many images, you will see that some of them are fairly large. What happens if we load them into memory and feed them to the mode? We might run out of memory.
# Consequently, when training networks on images or volumes one has to be careful about the input sizes. Also, for training in batches, i.e. feeding multiple images to the network at once, all images in the batch have to be of the same size. Hence all images need to be cropped or rescaled to the same size.
#
# For this exercise we implement a class that will apply a transformation `random crop`. Notice that we apply it to images and masks simultaneously to make sure they correspond despite the randomness.
#
# In case anybody is wondering why we have to bother to write a whole class for it instead of simply cropping the images directly in the dataset: we want to keep the code modular. We want to write one dataset object, and then we can try all the possible transforms with this one dataset. Similarly, we want to write one `RandomCrop` transform object, and then we can reuse it for any other image datasets we night have in the future.

# %%
class RandomCrop(object):
    """Crop randomly the input image and the output mask"""
    def __init__(self, crop_size):
        # check if the crop size is of a valid type
        assert isinstance(crop_size, (int, tuple, list))
        if isinstance(crop_size, int):
            # if the crop size is an integer, we use the same for both dimensions
            self.output_size = (crop_size, crop_size)
        else:
            assert len(crop_size) == 2
            self.crop_size = crop_size

    # this function makes our class callable 
    def __call__(self, sample):
        # we need to crop both input and mask at the same time
        assert len(sample) == 2
        image, mask = sample
        # the first dimension is channels, then width, then height
        w, h = image.shape[1:]
        new_w, new_h = self.output_size
        # choose a random place to crop
        top = np.random.randint(0, h - new_h) if h - new_h > 0 else 0
        left = np.random.randint(0, w - new_w) if w - new_w > 0 else 0
        # crop and return
        image = image[:, left: left + new_w, top: top + new_h]
        mask = mask[:, left: left + new_w, top: top + new_h]
        return image, mask

# %% [markdown]
# PS: PyTorch already has quite a bunch of all possible data transforms, so if you need one, check [here](https://pytorch.org/docs/stable/torchvision/transforms.html). The biggest problem with them is that they are clearly separated into transforms applied to PIL images (remember, we initially load the images as PIL.Image?) and torch.tensors (remember, we converted the images into tensors by calling transforms.ToTensor()?). This can be quite annoying if for some reason you might need to transorm your images to tensors before applying any other transforms or you don't want to use PIL library at all.

# %%
train_data = NucleiDataset(TRAIN_DATA_PATH, RandomCrop(256))
train_loader = DataLoader(train_data, batch_size=5, shuffle=True)

# %%
show_random_dataset_image(train_data)
# Out:
# Image size is {torch.Size([256, 256])}

# %% [markdown]
# And the same for the validation data:

# %%
VAL_DATA_PATH = 'nuclei_val_data'
val_data = NucleiDataset(VAL_DATA_PATH, RandomCrop(256))
val_loader = DataLoader(val_data, batch_size=5)

# %%
show_random_dataset_image(val_data)
# Out:
# Image size is {torch.Size([256, 256])}

# %% [markdown]
# ## The model: U-net
#
# Now we need to define the architecture of the model to use. This time we will use a [U-Net](https://lmb.informatik.uni-freiburg.de/people/ronneber/u-net/) that has proven to steadily outperform the other architectures in segmenting biological and medical images.
#
# The image of the model precisely describes all the building blocks you need to use to create it. All of them can be found in the list of PyTorch layers (modules) [here](https://pytorch.org/docs/stable/nn.html#convolution-layers).
#
# The U-net has an encoder-decoder structure:
# In the encoder pass, the input image is successively downsampled via max-pooling. In the decoder pass it is upsampled again via transposed convolutions.
# In adddition, it has skip connections, that bridge the output from an encoder to the corresponding decoder.

# %%
class UNet(nn.Module):
    """ UNet implementation
    Arguments:
      in_channels: number of input channels
      out_channels: number of output channels
      final_activation: activation applied to the network output
    """
    
    # _conv_block and _upsampler are just helper functions to
    # construct the model.
    # encapsulating them like so also makes it easy to re-use
    # the model implementation with different architecture elements
    
    # Convolutional block for single layer of the decoder / encoder
    # we apply to 2d convolutions with relu activation
    def _conv_block(self, in_channels, out_channels):
        return nn.Sequential(nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1),
                             nn.ReLU(),
                             nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1),
                             nn.ReLU())       


    # upsampling via transposed 2d convolutions
    def _upsampler(self, in_channels, out_channels):
        return nn.ConvTranspose2d(in_channels, out_channels,
                                kernel_size=2, stride=2)
    
    def __init__(self, in_channels=1, out_channels=1, 
                 final_activation=None):
        super().__init__()
        
        # the depth (= number of encoder / decoder levels) is
        # hard-coded to 4
        self.depth = 4

        # the final activation must either be None or a Module
        if final_activation is not None:
            assert isinstance(final_activation, nn.Module), "Activation must be torch module"
        
        # all lists of conv layers (or other nn.Modules with parameters) must be wraped
        # itnto a nn.ModuleList
        
        # modules of the encoder path
        self.encoder = nn.ModuleList([self._conv_block(in_channels, 16),
                                      self._conv_block(16, 32),
                                      self._conv_block(32, 64),
                                      self._conv_block(64, 128)])
        # the base convolution block
        self.base = self._conv_block(128, 256)
        # modules of the decoder path
        self.decoder = nn.ModuleList([self._conv_block(256, 128),
                                      self._conv_block(128, 64),
                                      self._conv_block(64, 32),
                                      self._conv_block(32, 16)])
        
        # the pooling layers; we use 2x2 MaxPooling
        self.poolers = nn.ModuleList([nn.MaxPool2d(2) for _ in range(self.depth)])
        # the upsampling layers
        self.upsamplers = nn.ModuleList([self._upsampler(256, 128),
                                         self._upsampler(128, 64),
                                         self._upsampler(64, 32),
                                         self._upsampler(32, 16)])
        # output conv and activation
        # the output conv is not followed by a non-linearity, because we apply
        # activation afterwards
        self.out_conv = nn.Conv2d(16, out_channels, 1)
        self.activation = final_activation
    
    def forward(self, input):
        x = input
        # apply encoder path
        encoder_out = []
        for level in range(self.depth):
            x = self.encoder[level](x)
            encoder_out.append(x)
            x = self.poolers[level](x)

        # apply base
        x = self.base(x)
        
        # apply decoder path
        encoder_out = encoder_out[::-1]
        for level in range(self.depth):
            x = self.upsamplers[level](x)
            x = self.decoder[level](torch.cat((x, encoder_out[level]), dim=1))
        
        # apply output conv and activation (if given)
        x = self.out_conv(x)
        if self.activation is not None:
            x = self.activation(x)
        return x

# %% [markdown]
# ## Loss and distance metrics
#
# Next, we need to define the loss function - a metric that will tell us how close we are to the desired output. This metric should be differentiable, since it needs to be backpropagated. The are [multiple losses](https://lars76.github.io/2018/09/27/loss-functions-for-segmentation.html) we could use for the segmentation task.
#
# Take a moment to think which one is better to use for our exercise. If you are not sure, don't forget that you can always google! Before you start implementing the loss yourself, take a look at the [losses](https://pytorch.org/docs/stable/nn.html#loss-functions) already implemented in PyTorch. You can also look for implementations on GitHub.
#
# __TASK__: implement your loss (or take one from pytorch):

# %%
loss_function = nn.MSELoss()

# %% [markdown]
# We will use the [Dice Coefficeint](https://en.wikipedia.org/wiki/S%C3%B8rensen%E2%80%93Dice_coefficient) to evaluate the network predictions.
# We can use it for validation if we interpret set $a$ as predictions and $b$ as labels. It is often used to evaluate segmentations with sparse foreground, because the denominator normalizes by the number of foreground pixels.
# The Dice Coefficient is closely related to Jaccard Index / Intersection over Union.

# %%
# sorensen dice coefficient implemented in torch
# the coefficient takes values in [0, 1], where 0 is
# the worst score, 1 is the best score
class DiceCoefficient(nn.Module):
    def __init__(self, eps=1e-6):
        super().__init__()
        self.eps = eps
        
    # the dice coefficient of two sets represented as vectors a, b ca be 
    # computed as (2 *|a b| / (a^2 + b^2))
    def forward(self, prediction, target):
        intersection = (prediction * target).sum()
        denominator = (prediction * prediction).sum() + (target * target).sum()
        return (2 * intersection / denominator.clamp(min=self.eps))

# %% [markdown]
# ## Training
#
# Let's start with writing training and validation functions. __TASK__: fix in all the TODOs to make the function run. You can use the function from the classification exercises as a template.

# %%
loss_function
# Out:
# MSELoss()

# %%
# apply training for one epoch
def train(model, loader, optimizer, loss_function, epoch, device,
          log_interval=100, log_image_interval=20, tb_logger=None):

    # set the model to train mode
    model.train()
    
    # iterate over the batches of this epoch
    for batch_id, (x, y) in enumerate(loader):
        # move input and target to the active device (either cpu or gpu)
        x, y = x.to(device), y.to(device)
        
        # zero the gradients for this iteration
        optimizer.zero_grad()
        
        # apply model, calculate loss and run backwards pass
        prediction = model(x)
        loss = loss_function(prediction, y[:, 0])
        loss.backward()
        optimizer.step()
        
        print(batch_id)
        print(log_interval)
        
        # log to console
        if batch_id % log_interval == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                  epoch, batch_id * len(x),
                  len(loader.dataset),
                  100. * batch_id / len(loader), loss.item()))

       # log to tensorboard
        if tb_logger is not None:
            step = epoch * len(loader) + batch_id
            tb_logger.add_scalar(tag='train_loss', scalar_value=loss.item(), global_step=step)
            # check if we log images in this iteration
            if step % log_image_interval == 0:
                tb_logger.add_images(tag='input', img_tensor=x.to('cpu'), global_step=step)
                tb_logger.add_images(tag='target', img_tensor=y.to('cpu'), global_step=step)
                tb_logger.add_images(tag='prediction', img_tensor=prediction.to('cpu').detach(), global_step=step)

# %%
# run validation after training epoch
def validate(model, loader, loss_function, metric, step=None, tb_logger=None):
    # set model to eval mode
    model.eval()
    # running loss and metric values
    val_loss = 0
    val_metric = 0
    
    mean_loss = 0
    predictions = []
    labels = []
    
    # disable gradients during validation
    with torch.no_grad():
        for x, y in loader:
            x = x.to(device)
            y = y.to(device)
            prediction = model(x)

            # update the loss
            # the loss function expects a 1d tensor, so we get rid of the second
            # singleton dimensions that is added by the loader when stacking across the batch function
            mean_loss += loss_function(prediction, y[:, 0]).item()

            # compute the most likely class predictions
            # note that 'max' returns a tuple with the
            # index of the maximun value (which correponds to the predicted class)
            # as second entry
            prediction = prediction.max(1, keepdim=True)[1]

            # store the predictions and labels
            predictions.append(prediction[:, 0].to('cpu').numpy())
            labels.append(y[:, 0].to('cpu').numpy())

        
        # iterate over validation loader and update loss and metric values
        # for x, y in loader:
        #    x, y = x.to(device), y.to(device)
        #    TODO: YOUR CODE HERE
    
    # normalize loss and metric
    val_loss /= len(loader)
    val_metric /= len(loader)
    
    if tb_logger is not None:
        assert step is not None, "Need to know the current step to log validation results"
        tb_logger.add_scalar(tag='val_loss', scalar_value=val_loss, global_step=step)
        tb_logger.add_scalar(tag='val_metric', scalar_value=val_metric, global_step=step)
        # we always log the last validation images
        tb_logger.add_images(tag='val_input', img_tensor=x.to('cpu'), global_step=step)
        tb_logger.add_images(tag='val_target', img_tensor=y.to('cpu'), global_step=step)
        tb_logger.add_images(tag='val_prediction', img_tensor=prediction.to('cpu'), global_step=step)
        
    print('\nValidate: Average loss: {:.4f}, Average Metric: {:.4f}\n'.format(val_loss, val_metric))

# %% [markdown]
# This time we will use GPU to train faster. Please make sure that your Notebook is running on GPU.

# %%
# check if we have  a gpu
if torch.cuda.is_available():
    print("GPU is available")
    device = torch.device("cuda")
else:
    print("GPU is not available")
    device = torch.device("cpu")
# Out:
# GPU is available

# %%
# start a tensorboard writer
logger = SummaryWriter('runs/Unet')
# %tensorboard --logdir runs
# Out:
# Reusing TensorBoard on port 6010 (pid 51450), started 6:54:20 ago. (Use '!kill 51450' to kill it.)
#       <iframe id="tensorboard-frame-9b4c161abcf8eea7" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-9b4c161abcf8eea7");
#           const url = new URL("/", window.location);
#           const port = 6010;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
from torch.optim import Adam

# %%
loss_function.to(device)
# Out:
# MSELoss()

# %%
optimizer
# Out:
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# )

# %%
# build a default unet with sigmoid activation
# to normalize predictions to [0, 1]
net = UNet(1, 1, final_activation=nn.Sigmoid())
# move the model to GPU
net = net.to(device)

# use adam optimizer
optimizer = Adam(net.parameters(), lr=1.e-3)

# build the dice coefficient metric
metric = DiceCoefficient()

# %%
train
# Out:
# <function __main__.train(model, loader, optimizer, loss_function, epoch, device, log_interval=100, log_image_interval=20, tb_logger=None)>

# %%
# train for 25 epochs
# during the training you can inspect the 
# predictions in the tensorboard
n_epochs = 25
for epoch in range(n_epochs):
    # train
    train(net, train_loader, optimizer, loss_function, epoch, device, tb_logger=logger)

    step = (epoch+1) * len(train_loader.dataset)
    # validate
    validate(net, val_loader, loss_function,
             device, step,
             tb_logger=logger)
# Out:
# 0
# 100
# Train Epoch: 0 [0/536 (0%)]	Loss: 0.119897
# 1
# 100
# 2
# 100
# 3
# 100
# 4
# 100
# 5
# 100
# 6
# 100
# 7
# 100
# 8
# 100
# 9
# 100
# 10
# 100
# 11
# 100
# 12
# 100
# 13
# 100
# 14
# 100
# 15
# 100
# 16
# 100
# 17
# 100
# 18
# 100
# 19
# 100
# 20
# 100
# 21
# 100
# 22
# 100
# 23
# 100
# 24
# 100
# 25
# 100
# 26
# 100
# 27
# 100
# 28
# 100
# 29
# 100
# 30
# 100
# 31
# 100
# 32
# 100
# 33
# 100
# 34
# 100
# 35
# 100
# 36
# 100
# 37
# 100
# 38
# 100
# 39
# 100
# 40
# 100
# 41
# 100
# 42
# 100
# 43
# 100
# 44
# 100
# 45
# 100
# 46
# 100
# 47
# 100
# 48
# 100
# 49
# 100
# 50
# 100
# 51
# 100
# 52
# 100
# 53
# 100
# 54
# 100
# 55
# 100
# 56
# 100
# 57
# 100
# 58
# 100
# 59
# 100
# 60
# 100
# 61
# 100
# 62
# 100
# 63
# 100
# 64
# 100
# 65
# 100
# 66
# 100
# 67
# 100
# 68
# 100
# 69
# 100
# 70
# 100
# 71
# 100
# 72
# 100
# 73
# 100
# 74
# 100
# 75
# 100
# 76
# 100
# 77
# 100
# 78
# 100
# 79
# 100
# 80
# 100
# 81
# 100
# 82
# 100
# 83
# 100
# 84
# 100
# 85
# 100
# 86
# 100
# 87
# 100
# 88
# 100
# 89
# 100
# 90
# 100
# 91
# 100
# 92
# 100
# 93
# 100
# 94
# 100
# 95
# 100
# 96
# 100
# 97
# 100
# 98
# 100
# 99
# 100
# 100
# 100
# Train Epoch: 0 [500/536 (93%)]	Loss: 0.091342
# 101
# 100
# 102
# 100
# 103
# 100
# 104
# 100
# 105
# 100
# 106
# 100
# 107
# 100
# /opt/conda/envs/dl-pytorch/lib/python3.8/site-packages/torch/nn/modules/loss.py:528: UserWarning: Using a target size (torch.Size([4, 256, 256])) that is different to the input size (torch.Size([4, 1, 256, 256])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Validate: Average loss: 0.0000, Average Metric: 0.0000
#
# 0
# 100
# Train Epoch: 1 [0/536 (0%)]	Loss: 0.072559
# 1
# 100
# 2
# 100
# 3
# 100
# 4
# 100
# 5
# 100
# 6
# 100
# 7
# 100
# 8
# 100
# 9
# 100
# 10
# 100
# 11
# 100
# 12
# 100
# 13
# 100
# 14
# 100
# 15
# 100
# 16
# 100
# 17
# 100
# 18
# 100
# 19
# 100
# 20
# 100
# 21
# 100
# 22
# 100
# 23
# 100
# 24
# 100
# 25
# 100
# 26
# 100
# 27
# 100
# 28
# 100
# 29
# 100
# 30
# 100
# 31
# 100
# 32
# 100
# 33
# 100
# 34
# 100
# 35
# 100
# 36
# 100
# 37
# 100
# 38
# 100
# 39
# 100
# 40
# 100
# 41
# 100
# 42
# 100
# 43
# 100
# 44
# 100
# 45
# 100
# 46
# 100
# 47
# 100
# 48
# 100
# 49
# 100
# 50
# 100
# 51
# 100
# 52
# 100
# 53
# 100
# 54
# 100
# 55
# 100
# 56
# 100
# 57
# 100
# 58
# 100
# 59
# 100
# 60
# 100
# 61
# 100
# 62
# 100
# 63
# 100
# 64
# 100
# 65
# 100
# 66
# 100
# 67
# 100
# 68
# 100
# 69
# 100
# 70
# 100
# 71
# 100
# 72
# 100
# 73
# 100
# 74
# 100
# 75
# 100
# 76
# 100
# 77
# 100
# 78
# 100
# 79
# 100
# 80
# 100
# 81
# 100
# 82
# 100
# 83
# 100
# 84
# 100
# 85
# 100
# 86
# 100
# 87
# 100
# 88
# 100
# 89
# 100
# 90
# 100
# 91
# 100
# 92
# 100
# 93
# 100
# 94
# 100
# 95
# 100
# 96
# 100
# 97
# 100
# 98
# 100
# 99
# 100
# 100
# 100
# Train Epoch: 1 [500/536 (93%)]	Loss: 0.075107
# 101
# 100
# 102
# 100
# 103
# 100
# 104
# 100
# 105
# 100
# 106
# 100
# 107
# 100
#
# Validate: Average loss: 0.0000, Average Metric: 0.0000
#
# 0
# 100
# Train Epoch: 2 [0/536 (0%)]	Loss: 0.116714
# 1
# 100
# 2
# 100
# 3
# 100
# 4
# 100
# 5
# 100
# 6
# 100
# 7
# 100
# 8
# 100
# 9
# 100
# 10
# 100
# 11
# 100
# 12
# 100
# 13
# 100
# 14
# 100
# 15
# 100
# 16
# 100
# 17
# 100
# 18
# 100
# 19
# 100
# 20
# 100
# 21
# 100
# 22
# 100
# 23
# 100
# 24
# 100
# 25
# 100
# 26
# 100
# 27
# 100
# 28
# 100
# 29
# 100
# 30
# 100
# 31
# 100
# 32
# 100
# 33
# 100
# 34
# 100
# 35
# 100
# 36
# 100
# 37
# 100
# 38
# 100
# 39
# 100
# 40
# 100
# 41
# 100
# 42
# 100
# 43
# 100
# 44
# 100
# 45
# 100
# 46
# 100
# 47
# 100
# 48
# 100
# 49
# 100
# 50
# 100
# 51
# 100
# 52
# 100
# 53
# 100
# 54
# 100
# 55
# 100
# 56
# 100
# 57
# 100
# 58
# 100
# 59
# 100
# 60
# 100
# 61
# 100
# 62
# 100
# 63
# 100
# 64
# 100
# 65
# 100
# 66
# 100
# 67
# 100
# 68
# 100
# 69
# 100
# 70
# 100
# 71
# 100
# 72
# 100
# 73
# 100
# 74
# 100
# 75
# 100
# 76
# 100
# 77
# 100
# 78
# 100
# 79
# 100
# 80
# 100
# 81
# 100
# 82
# 100
# 83
# 100
# 84
# 100
# 85
# 100
# 86
# 100
# 87
# 100
# 88
# 100
# 89
# 100
# 90
# 100
# 91
# 100
# 92
# 100
# 93
# 100
# 94
# 100
# 95
# 100
# 96
# 100
# 97
# 100
# 98
# 100
# 99
# 100
# 100
# 100
# Train Epoch: 2 [500/536 (93%)]	Loss: 0.115335
# 101
# 100
# 102
# 100
# 103
# 100
# 104
# 100
# 105
# 100
# 106
# 100
# 107
# 100
#
# Validate: Average loss: 0.0000, Average Metric: 0.0000
#
# 0
# 100
# Train Epoch: 3 [0/536 (0%)]	Loss: 0.092780
# 1
# 100
# 2
# 100
# 3
# 100
# 4
# 100
# 5
# 100
# 6
# 100
# 7
# 100
# 8
# 100
# 9
# 100
# 10
# 100
# 11
# 100
# 12
# 100
# 13
# 100
# 14
# 100
# 15
# 100
# 16
# 100
# 17
# 100
# 18
# 100
# 19
# 100
# 20
# 100
# 21
# 100
# 22
# 100
# 23
# 100
# 24
# 100
# 25
# 100
# 26
# 100
# 27
# 100
# 28
# 100
# 29
# 100
# 30
# 100
# 31
# 100
# 32
# 100
# 33
# 100
# 34
# 100
# 35
# 100
# 36
# 100
# 37
# 100
# 38
# 100
# 39
# 100
# 40
# 100
# 41
# 100
# 42
# 100
# 43
# 100
# 44
# 100
# 45
# 100
# 46
# 100
# 47
# 100
# 48
# 100
# 49
# 100
# 50
# 100
# 51
# 100
# 52
# 100
# 53
# 100
# 54
# 100
# 55
# 100
# 56
# 100
# 57
# 100
# 58
# 100
# 59
# 100
# 60
# 100
# 61
# 100
# 62
# 100
# 63
# 100
# 64
# 100
# 65
# 100
# 66
# 100
# 67
# 100
# 68
# 100
# 69
# 100
# 70
# 100
# 71
# 100
# 72
# 100
# 73
# 100
# 74
# 100
# 75
# 100
# 76
# 100
# 77
# 100
# 78
# 100
# 79
# 100
# 80
# 100
# 81
# 100
# 82
# 100
# 83
# 100
# 84
# 100
# 85
# 100
# 86
# 100
# 87
# 100
# 88
# 100
# 89
# 100
# 90
# 100
# 91
# 100
# 92
# 100
# 93
# 100
# 94
# 100
# 95
# 100
# 96
# 100
# 97
# 100
# 98
# 100
# 99
# 100
# 100
# 100
# Train Epoch: 3 [500/536 (93%)]	Loss: 0.079120
# 101
# 100
# 102
# 100
# 103
# 100
# 104
# 100
# 105
# 100
# 106
# 100
# 107
# 100
#
# Validate: Average loss: 0.0000, Average Metric: 0.0000
#
# 0
# 100
# Train Epoch: 4 [0/536 (0%)]	Loss: 0.046185
# 1
# 100
# 2
# 100
# 3
# 100
# 4
# 100
# 5
# 100
# 6
# 100
# 7
# 100
# 8
# 100
# 9
# 100
# 10
# 100
# 11
# 100
# 12
# 100
# 13
# 100
# 14
# 100
# 15
# 100
# 16
# 100
# 17
# 100
# 18
# 100
# 19
# 100
# 20
# 100
# 21
# 100
# 22
# 100
# 23
# 100
# 24
# 100
# 25
# 100
# 26
# 100
# 27
# 100
# 28
# 100
# 29
# 100
# 30
# 100
# 31
# 100
# 32
# 100
# 33
# 100
# 34
# 100
# 35
# 100
# 36
# 100
# 37
# 100
# 38
# 100
# 39
# 100
# 40
# 100
# 41
# 100
# 42
# 100
# 43
# 100
# 44
# 100
# 45
# 100
# 46
# 100
# 47
# 100
# 48
# 100
# 49
# 100
# 50
# 100
# 51
# 100
# 52
# 100
# 53
# 100
# 54
# 100
# 55
# 100
# 56
# 100
# 57
# 100
# 58
# 100
# 59
# 100
# 60
# 100
# 61
# 100
# 62
# 100
# 63
# 100
# 64
# 100
# 65
# 100
# 66
# 100
# 67
# 100
# 68
# 100
# 69
# 100
# 70
# 100
# 71
# 100
# 72
# 100
# 73
# 100
# 74
# 100
# 75
# 100
# 76
# 100
# 77
# 100
# 78
# 100
# 79
# 100
# 80
# 100
# 81
# 100
# 82
# 100
# 83
# 100
# 84
# 100
# 85
# 100
# 86
# 100
# 87
# 100
# 88
# 100
# 89
# 100
# 90
# 100
# 91
# 100
# 92
# 100
# 93
# 100
# 94
# 100
# 95
# 100
# 96
# 100
# 97
# 100
# 98
# 100
# 99
# 100
# 100
# 100
# Train Epoch: 4 [500/536 (93%)]	Loss: 0.162292
# 101
# 100
# 102
# 100
# 103
# 100
# 104
# 100
# 105
# 100
# 106
# 100
# 107
# 100
#
# Validate: Average loss: 0.0000, Average Metric: 0.0000
#
# 0
# 100
# Train Epoch: 5 [0/536 (0%)]	Loss: 0.069373
# 1
# 100
# 2
# 100
# 3
# 100
# 4
# 100
# 5
# 100
# 6
# 100
# 7
# 100
# 8
# 100
# 9
# 100
# 10
# 100
# 11
# 100
# 12
# 100
# 13
# 100
# 14
# 100
# 15
# 100
# 16
# 100
# 17
# 100
# 18
# 100
# 19
# 100
# 20
# 100
# 21
# 100
# 22
# 100
# 23
# 100
# 24
# 100
# 25
# 100
# 26
# 100
# 27
# 100
# 28
# 100
# 29
# 100
# 30
# 100
# 31
# 100
# 32
# 100
# 33
# 100
# 34
# 100
# 35
# 100
# 36
# 100
# 37
# 100
# 38
# 100
# 39
# 100
# 40
# 100
# 41
# 100
# 42
# 100
# 43
# 100
# 44
# 100
# 45
# 100
# 46
# 100
# 47
# 100
# 48
# 100
# 49
# 100
# 50
# 100
# 51
# 100
# 52
# 100
# 53
# 100
# 54
# 100
# 55
# 100
# 56
# 100
# 57
# 100
# 58
# 100
# 59
# 100
# 60
# 100
# 61
# 100
# 62
# 100
# 63
# 100
# 64
# 100
# 65
# 100
# 66
# 100
# 67
# 100
# 68
# 100
# 69
# 100
# 70
# 100
# 71
# 100
# 72
# 100
# 73
# 100
# 74
# 100
# 75
# 100
# 76
# 100
# 77
# 100
# 78
# 100
# 79
# 100
# 80
# 100
# 81
# 100
# 82
# 100
# 83
# 100
# 84
# 100
# 85
# 100
# 86
# 100
# 87
# 100
# 88
# 100
# 89
# 100
# 90
# 100
# 91
# 100
# 92
# 100
# 93
# 100
# 94
# 100
# 95
# 100
# 96
# 100
# 97
# 100
# 98
# 100
# 99
# 100
# 100
# 100
# Train Epoch: 5 [500/536 (93%)]	Loss: 0.189957
# 101
# 100
# 102
# 100
# 103
# 100
# 104
# 100
# 105
# 100
# 106
# 100
# 107
# 100
#
# Validate: Average loss: 0.0000, Average Metric: 0.0000
#
# 0
# 100
# Train Epoch: 6 [0/536 (0%)]	Loss: 0.042404
# 1
# 100
# 2
# 100
# 3
# 100
# 4
# 100
# 5
# 100
# 6
# 100
# 7
# 100
# 8
# 100
# 9
# 100
# 10
# 100
# 11
# 100
# 12
# 100
# 13
# 100
# 14
# 100
# 15
# 100
# 16
# 100
# 17
# 100
# 18
# 100
# 19
# 100
# 20
# 100
# 21
# 100
# 22
# 100
# 23
# 100
# 24
# 100
# 25
# 100
# 26
# 100
# 27
# 100
# 28
# 100
# 29
# 100
# 30
# 100
# 31
# 100
# 32
# 100
# 33
# 100
# 34
# 100
# 35
# 100
# 36
# 100
# 37
# 100
# 38
# 100
# 39
# 100
# 40
# 100
# 41
# 100
# 42
# 100
# 43
# 100
# 44
# 100
# 45
# 100
# 46
# 100
# 47
# 100
# 48
# 100
# 49
# 100
# 50
# 100
# 51
# 100
# 52
# 100
# 53
# 100
# 54
# 100
# 55
# 100
# 56
# 100
# 57
# 100
# 58
# 100
# 59
# 100
# 60
# 100
# 61
# 100
# 62
# 100
# 63
# 100
# 64
# 100
# 65
# 100
# 66
# 100
# 67
# 100
# 68
# 100
# 69
# 100
# 70
# 100
# 71
# 100
# 72
# 100
# 73
# 100
# 74
# 100
# 75
# 100
# 76
# 100
# 77
# 100
# 78
# 100
# 79
# 100
# 80
# 100
# 81
# 100
# 82
# 100
# 83
# 100
# 84
# 100
# 85
# 100
# 86
# 100
# 87
# 100
# 88
# 100
# 89
# 100
# 90
# 100
# 91
# 100
# 92
# 100
# 93
# 100
# 94
# 100
# 95
# 100
# 96
# 100
# 97
# 100
# 98
# 100
# 99
# 100
# 100
# 100
# Train Epoch: 6 [500/536 (93%)]	Loss: 0.168161
# 101
# 100
# 102
# 100
# 103
# 100
# 104
# 100
# 105
# 100
# 106
# 100
# 107
# 100
#
# Validate: Average loss: 0.0000, Average Metric: 0.0000
#
# 0
# 100
# Train Epoch: 7 [0/536 (0%)]	Loss: 0.052225
# 1
# 100
# 2
# 100
# 3
# 100
# 4
# 100
# 5
# 100
# 6
# 100
# 7
# 100
# 8
# 100
# 9
# 100
# 10
# 100
# 11
# 100
# 12
# 100
# 13
# 100
# 14
# 100
# 15
# 100
# 16
# 100
# 17
# 100
# 18
# 100
# 19
# 100
# 20
# 100
# 21
# 100
# 22
# 100
# 23
# 100
# 24
# 100
# 25
# 100
# 26
# 100
# 27
# 100
# 28
# 100
# 29
# 100
# 30
# 100
# 31
# 100
# 32
# 100
# 33
# 100
# 34
# 100
# 35
# 100
# 36
# 100
# 37
# 100
# 38
# 100
# 39
# 100
# 40
# 100
# 41
# 100
# 42
# 100
# 43
# 100
# 44
# 100
# 45
# 100
# 46
# 100
# 47
# 100
# 48
# 100
# 49
# 100
# 50
# 100
# 51
# 100
# 52
# 100
# 53
# 100
# 54
# 100
# 55
# 100
# 56
# 100
# 57
# 100
# 58
# 100
# 59
# 100
# 60
# 100
# 61
# 100
# 62
# 100
# 63
# 100
# 64
# 100
# 65
# 100
# 66
# 100
# 67
# 100
# 68
# 100
# 69
# 100
# 70
# 100
# 71
# 100
# 72
# 100
# 73
# 100
# 74
# 100
# 75
# 100
# 76
# 100
# 77
# 100
# 78
# 100
# 79
# 100
# 80
# 100
# 81
# 100
# 82
# 100
# 83
# 100
# 84
# 100
# 85
# 100
# 86
# 100
# 87
# 100
# 88
# 100
# 89
# 100
# 90
# 100
# 91
# 100
# 92
# 100
# 93
# 100
# 94
# 100
# 95
# 100
# 96
# 100
# 97
# 100
# 98
# 100
# 99
# 100
# 100
# 100
# Train Epoch: 7 [500/536 (93%)]	Loss: 0.124677
# 101
# 100
# 102
# 100
# 103
# 100
# 104
# 100
# 105
# 100
# 106
# 100
# 107
# 100
#
# Validate: Average loss: 0.0000, Average Metric: 0.0000
#
# 0
# 100
# Train Epoch: 8 [0/536 (0%)]	Loss: 0.096710
# 1
# 100
# 2
# 100
# 3
# 100
# 4
# 100
# 5
# 100
# 6
# 100
# 7
# 100
# 8
# 100
# 9
# 100
# 10
# 100
# 11
# 100
# 12
# 100
# 13
# 100
# 14
# 100
# 15
# 100
# 16
# 100
# 17
# 100
# 18
# 100
# 19
# 100
# 20
# 100
# 21
# 100
# 22
# 100
# 23
# 100
# 24
# 100
# 25
# 100
# 26
# 100
# 27
# 100
# 28
# 100
# 29
# 100
# 30
# 100
# 31
# 100
# 32
# 100
# 33
# 100
# 34
# 100
# 35
# 100
# 36
# 100
# 37
# 100
# 38
# 100
# 39
# 100
# 40
# 100
# 41
# 100
# 42
# 100
# 43
# 100
# 44
# 100
# 45
# 100
# 46
# 100
# 47
# 100
# 48
# 100
# 49
# 100
# 50
# 100
# 51
# 100
# 52
# 100
# 53
# 100
# 54
# 100
# 55
# 100
# 56
# 100
# 57
# 100
# 58
# 100
# 59
# 100
# 60
# 100
# 61
# 100
# 62
# 100
# 63
# 100
# 64
# 100
# 65
# 100
# 66
# 100
# 67
# 100
# 68
# 100
# 69
# 100
# 70
# 100
# 71
# 100
# 72
# 100
# 73
# 100
# 74
# 100
# 75
# 100
# 76
# 100
# 77
# 100
# 78
# 100
# 79
# 100
# 80
# 100
# 81
# 100
# 82
# 100
# 83
# 100
# 84
# 100
# 85
# 100
# 86
# 100
# 87
# 100
# 88
# 100
# 89
# 100
# 90
# 100
# 91
# 100
# 92
# 100
# 93
# 100
# 94
# 100
# 95
# 100
# 96
# 100
# 97
# 100
# 98
# 100
# 99
# 100
# 100
# 100
# Train Epoch: 8 [500/536 (93%)]	Loss: 0.125513
# 101
# 100
# 102
# 100
# 103
# 100
# 104
# 100
# 105
# 100
# 106
# 100
# 107
# 100
#
# Validate: Average loss: 0.0000, Average Metric: 0.0000
#
# 0
# 100
# Train Epoch: 9 [0/536 (0%)]	Loss: 0.113928
# 1
# 100
# 2
# 100
# 3
# 100
# 4
# 100
# 5
# 100
# 6
# 100
# 7
# 100
# 8
# 100
# 9
# 100
# 10
# 100
# 11
# 100
# 12
# 100
# 13
# 100
# 14
# 100
# 15
# 100
# 16
# 100
# 17
# 100
# 18
# 100
# 19
# 100
# 20
# 100
# 21
# 100
# 22
# 100
# 23
# 100
# 24
# 100
# 25
# 100
# 26
# 100
# 27
# 100
# 28
# 100
# 29
# 100
# 30
# 100
# 31
# 100
# 32
# 100
# 33
# 100
# 34
# 100
# 35
# 100
# 36
# 100
# 37
# 100
# 38
# 100
# 39
# 100
# 40
# 100
# 41
# 100
# 42
# 100
# 43
# 100
# 44
# 100
# 45
# 100
# 46
# 100
# 47
# 100
# 48
# 100
# 49
# 100
# 50
# 100
# 51
# 100
# 52
# 100
# 53
# 100
# 54
# 100
# 55
# 100
# 56
# 100
# 57
# 100
# 58
# 100
# 59
# 100
# 60
# 100
# 61
# 100
# 62
# 100
# 63
# 100
# 64
# 100
# 65
# 100
# 66
# 100
# 67
# 100
# 68
# 100
# 69
# 100
# 70
# 100
# 71
# 100
# 72
# 100
# 73
# 100
# 74
# 100
# 75
# 100
# 76
# 100
# 77
# 100
# 78
# 100
# 79
# 100
# 80
# 100
# 81
# 100
# 82
# 100
# 83
# 100
# 84
# 100
# 85
# 100
# 86
# 100
# 87
# 100
# 88
# 100
# 89
# 100
# 90
# 100
# 91
# 100
# 92
# 100
# 93
# 100
# 94
# 100
# 95
# 100
# 96
# 100
# 97
# 100
# 98
# 100
# 99
# 100
# 100
# 100
# Train Epoch: 9 [500/536 (93%)]	Loss: 0.120239
# 101
# 100
# 102
# 100
# 103
# 100
# 104
# 100
# 105
# 100
# 106
# 100
# 107
# 100
#
# Validate: Average loss: 0.0000, Average Metric: 0.0000
#
# 0
# 100
# Train Epoch: 10 [0/536 (0%)]	Loss: 0.194699
# 1
# 100
# 2
# 100
# 3
# 100
# 4
# 100
# 5
# 100
# 6
# 100
# 7
# 100
# 8
# 100
# 9
# 100
# 10
# 100
# 11
# 100
# 12
# 100
# 13
# 100
# 14
# 100
# 15
# 100
# 16
# 100
# 17
# 100
# 18
# 100
# 19
# 100
# 20
# 100
# 21
# 100
# 22
# 100
# 23
# 100
# 24
# 100
# 25
# 100
# 26
# 100
# 27
# 100
# 28
# 100
# 29
# 100
# 30
# 100
# 31
# 100
# 32
# 100
# 33
# 100
# 34
# 100
# 35
# 100
# 36
# 100
# 37
# 100
# 38
# 100
# 39
# 100
# 40
# 100
# 41
# 100
# 42
# 100
# 43
# 100
# 44
# 100
# 45
# 100
# 46
# 100
# 47
# 100
# 48
# 100
# 49
# 100
# 50
# 100
# 51
# 100
# 52
# 100
# 53
# 100
# 54
# 100
# 55
# 100
# 56
# 100
# 57
# 100
# 58
# 100
# 59
# 100
# 60
# 100
# 61
# 100
# 62
# 100
# 63
# 100
# 64
# 100
# 65
# 100
# 66
# 100
# 67
# 100
# 68
# 100
# 69
# 100
# 70
# 100
# 71
# 100
# 72
# 100
# 73
# 100
# 74
# 100
# 75
# 100
# 76
# 100
# 77
# 100
# 78
# 100
# 79
# 100
# 80
# 100
# 81
# 100
# 82
# 100
# 83
# 100
# 84
# 100
# 85
# 100
# 86
# 100
# 87
# 100
# 88
# 100
# 89
# 100
# 90
# 100
# 91
# 100
# 92
# 100
# 93
# 100
# 94
# 100
# 95
# 100
# 96
# 100
# 97
# 100
# 98
# 100
# 99
# 100
# 100
# 100
# Train Epoch: 10 [500/536 (93%)]	Loss: 0.223999
# 101
# 100
# 102
# 100
# 103
# 100
# 104
# 100
# 105
# 100
# 106
# 100
# 107
# 100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_10692/496849698.py in <module>
#       9     step = (epoch+1) * len(train_loader.dataset)
#      10     # validate
# ---> 11     validate(net, val_loader, loss_function,
#      12              device, step,
#      13              tb_logger=logger)
#
# /tmp/ipykernel_10692/3335324362.py in validate(model, loader, loss_function, metric, step, tb_logger)
#      13     # disable gradients during validation
#      14     with torch.no_grad():
# ---> 15         for x, y in loader:
#      16             x = x.to(device)
#      17             y = y.to(device)
#
# /opt/conda/envs/dl-pytorch/lib/python3.8/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     519             if self._sampler_iter is None:
#     520                 self._reset()
# --> 521             data = self._next_data()
#     522             self._num_yielded += 1
#     523             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /opt/conda/envs/dl-pytorch/lib/python3.8/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#     559     def _next_data(self):
#     560         index = self._next_index()  # may raise StopIteration
# --> 561         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     562         if self._pin_memory:
#     563             data = _utils.pin_memory.pin_memory(data)
#
# /opt/conda/envs/dl-pytorch/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# /opt/conda/envs/dl-pytorch/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# /tmp/ipykernel_10692/629117467.py in __getitem__(self, idx)
#      35             # erode the image by one pixel
#      36             # TASK: guess why is this done?
# ---> 37             one_nuclei_mask = binary_erosion(one_nuclei_mask)
#      38             one_nuclei_mask = self.mask_transforms(one_nuclei_mask)
#      39             # add this nucleus to the mask
#
# /opt/conda/envs/dl-pytorch/lib/python3.8/site-packages/scipy/ndimage/morphology.py in binary_erosion(input, structure, iterations, mask, output, border_value, origin, brute_force)
#     384
#     385     """
# --> 386     return _binary_erosion(input, structure, iterations, mask,
#     387                            output, border_value, origin, 0, brute_force)
#     388
#
# /opt/conda/envs/dl-pytorch/lib/python3.8/site-packages/scipy/ndimage/morphology.py in _binary_erosion(input, structure, iterations, mask, output, border_value, origin, invert, brute_force)
#     220         raise TypeError('iterations parameter should be an integer') from e
#     221
# --> 222     input = numpy.asarray(input)
#     223     if numpy.iscomplexobj(input):
#     224         raise TypeError('Complex type not supported')
#
# /opt/conda/envs/dl-pytorch/lib/python3.8/site-packages/PIL/Image.py in __array__(self, dtype)
#     696             new["data"] = self.tobytes("raw", "L")
#     697         else:
# --> 698             new["data"] = self.tobytes()
#     699
#     700         class ArrayData:
#
# /opt/conda/envs/dl-pytorch/lib/python3.8/site-packages/PIL/Image.py in tobytes(self, encoder_name, *args)
#     742             args = self.mode
#     743
# --> 744         self.load()
#     745
#     746         # unpack data
#
# /opt/conda/envs/dl-pytorch/lib/python3.8/site-packages/PIL/ImageFile.py in load(self)
#     253
#     254                             b = b + s
# --> 255                             n, err_code = decoder.decode(b)
#     256                             if n < 0:
#     257                                 break
#
# KeyboardInterrupt:

# %% [markdown]
# ## Additional Exercises
#
# 1. Implement and compare at least 2 of the following architecture variants of the U-Net:
#     * use [Dropout](https://pytorch.org/docs/stable/nn.html#dropout-layers) in the decoder path
#     * use [BatchNorm](https://pytorch.org/docs/stable/nn.html#torch.nn.BatchNorm2d) to normalize layer inputs
#     * use [GroupNorm](https://pytorch.org/docs/stable/nn.html#torch.nn.GroupNorm) to normalize convolutional group inputs
#     * use [ELU-Activations](https://pytorch.org/docs/stable/nn.html#torch.nn.ELU) instead of ReLU-Activations
#
# 2. Use the Dice coefficient as loss function. Before we only used it for validation, but it is differentiable and can thus also be used as loss. Compare to the results from exercise 2.
# Hint: The optimizer we use finds minima of the loss, but the minimal value for the Dice coefficient corresponds to a bad segmentation. How do we need to change the Dice coefficient to use it as loss nonetheless?
#
# 3. Add one more layer to the U-net model (currently it has 4). Compare the results.

# %% [markdown]
# ## Advanced Exercises
#
# 1. Visualize the graph (model) that we are using with TensorBoard
# 2. Write your own data transform (e.g., RandomRotate)
