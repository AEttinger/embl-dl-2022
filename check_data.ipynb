# %%
import h5py
import os
from glob import glob
from skimage.io import imread

# %%
image_files = sorted(glob('../dl-course-2022/07_esc_3d_colonies/images_hdf5/*.hdf5'))
masks_files = sorted(glob('../dl-course-2022/07_esc_3d_colonies/masks_filled/*.hdf5'))

# %%
with h5py.File(image_files[0], 'r') as f:
    img = list(f['dataset'])

# %%
with h5py.File(masks_files[0], 'r') as f:
    mask = list(f['dataset'])

# %%
from matplotlib import pyplot as plt

# %%
img[0].shape
# Out:
# (1024, 1024)

# %%
image_files[0]
# Out:
# '../dl-course-2022/07_esc_3d_colonies/images_hdf5/esc_siRDNA_9.hdf5'

# %%
masks_files[0]
# Out:
# '../dl-course-2022/07_esc_3d_colonies/masks_filled/esc_siRDNA_0.hdf5'

# %%
plt.imshow(mask[12])

# %%
plt.imshow(img[12])
